# %% [markdown]
# # Sistemas de Big Data
# ## Proyecto de manipulación de datos
# **Autores:** Nicole Díaz y Enrique Ángel

# %% [markdown]
# IMPORTACIÓN LIBRERÍAS:D

# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa
import seaborn as sns
from sqlalchemy import create_engine, text
import matplotlib.pyplot as plt


df_completo = pd.read_csv("csv/ventas.csv")
df_completo
# Out:
#       ID  ID_Pedido ID_Factura       Supermercado      Ciudad Tipo_cliente  \
# 0      1      56904   56904-C1  Perfumes Olorosos        Vigo    Existente
# 1      2      56904   56904-C2         El Cercano  Pontevedra    Existente
# 2      3      56904   56904-C3         El Primero        Vigo    Existente
# 3      4      56904   56904-C4  Perfumes Olorosos        Vigo    Existente
# 4      5      56904   56904-C5            El Caro      Nigrán    Existente
# ..   ...        ...        ...                ...         ...          ...
# 303  304      30066   30066-C3      Mercería Coso    A Coruña    Existente
# 304  305      30066   30066-C4      Mercería Coso    A Coruña    Existente
# 305  306      30066   30066-C5  Perfumes Olorosos        Vigo    Existente
# 306  307      30066   30066-C6         El Primero        Vigo    Existente
# 307  308      30066   30066-C7      Mercería Coso    A Coruña    Existente
#
# ...

# %% [markdown]
# VISUALIZACIÓN :DATAFRAME DE DIRECCIONES

# %%
df_direcciones = pd.read_csv("csv/DIRECCIONES.csv")
df_direcciones
# Out:
#     ID  ID_Pedido                              dir_entrega       tipo_entrega  \
# 0    7      56904                   Gran vía 24 1C, Madrid            Correos
# 1    8      84698        Rúa Rosalía de castro 28 4B, Vigo          Domicilio
# 2    9      14325                Avenida de Europa 2, Vigo            Correos
# 3   10      68893                   c/Orense 25 2C, Madrid          Domicilio
# 4   11      72994                    c/agua 25 3D, Sevilla  Punto de recogida
# 5   12      82407                 c/San Lorenzo 12, Málaga          Domicilio
# 6   13      74285    Avinguda de Manuel Azaña 4, Barcelona          Domicilio
# 7   14       5364         Avenida de Casablanca 45, Madrid            Correos
# 8   15      80407           Calle de Canarias 1 2B, Madrid  Punto de recogida
# 9   16      18447                          c/Esla 34, León          Domicilio
# 10  17      76092    Cami Assagador del Morro 12, Valencia          Domicilio
# ...

# %% [markdown]
# ----

# %% [markdown]
# ### INSPECCIÓN INICIAL

# %%
display(df_direcciones.head())
print(df_direcciones.info())
print("Nulos:", df_direcciones.isnull().sum())
print("Duplicados:", df_direcciones.duplicated().sum())
print("==================================================")
display(df_completo.head())
print(df_completo.info())
print("Nulos:", df_completo.isnull().sum())
print("Duplicados:", df_completo.duplicated().sum())
# Out:
#    ID  ID_Pedido                        dir_entrega       tipo_entrega  \
# 0   7      56904             Gran vía 24 1C, Madrid            Correos
# 1   8      84698  Rúa Rosalía de castro 28 4B, Vigo          Domicilio
# 2   9      14325          Avenida de Europa 2, Vigo            Correos
# 3  10      68893             c/Orense 25 2C, Madrid          Domicilio
# 4  11      72994              c/agua 25 3D, Sevilla  Punto de recogida
#
#                          email
# 0      twana_ellwood@yahoo.com
# 1        emery_aitken@mail.com
# 2  thomasina_stone@hotmail.com
# 3     justin_higgins@gmail.com
# 4    liliana_wilde@outlook.com
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            60 non-null     int64
#  1   ID_Pedido     60 non-null     int64
#  2   dir_entrega   60 non-null     object
# ...

# %% [markdown]
# -----------

# %% [markdown]
# ### AÑADIMOS LA NUEVA COLUMNA TIPO DE ENTREGA
# -----------

# %%
# merge funcion con el on: donde va las columnas comunes, how el tipo de union: 
df_completo = df_completo.merge(df_direcciones[['ID_Pedido', 'tipo_entrega']], on='ID_Pedido', how='left')
df_completo
# Out:
#       ID  ID_Pedido ID_Factura       Supermercado      Ciudad Tipo_cliente  \
# 0      1      56904   56904-C1  Perfumes Olorosos        Vigo    Existente
# 1      2      56904   56904-C2         El Cercano  Pontevedra    Existente
# 2      3      56904   56904-C3         El Primero        Vigo    Existente
# 3      4      56904   56904-C4  Perfumes Olorosos        Vigo    Existente
# 4      5      56904   56904-C5            El Caro      Nigrán    Existente
# ..   ...        ...        ...                ...         ...          ...
# 316  304      30066   30066-C3      Mercería Coso    A Coruña    Existente
# 317  305      30066   30066-C4      Mercería Coso    A Coruña    Existente
# 318  306      30066   30066-C5  Perfumes Olorosos        Vigo    Existente
# 319  307      30066   30066-C6         El Primero        Vigo    Existente
# 320  308      30066   30066-C7      Mercería Coso    A Coruña    Existente
#
# ...

# %% [markdown]
# ### AÑADIMOS LA COLUMNA DE NOMBRE DE USUARIOS
# -----------

# %%
df_completo = df_completo.merge(
    df_direcciones[['ID_Pedido', 'email']],
    on='ID_Pedido',
    how='left'
)
df_completo['nombre_usuario'] = df_completo['email'].str.split('@', expand=True)[0]
df_completo['nombre_usuario'] = df_completo['nombre_usuario'].fillna('DESCONOCIDO')
df_completo
# Out:
#       ID  ID_Pedido ID_Factura       Supermercado      Ciudad Tipo_cliente  \
# 0      1      56904   56904-C1  Perfumes Olorosos        Vigo    Existente
# 1      2      56904   56904-C2         El Cercano  Pontevedra    Existente
# 2      3      56904   56904-C3         El Primero        Vigo    Existente
# 3      4      56904   56904-C4  Perfumes Olorosos        Vigo    Existente
# 4      5      56904   56904-C5            El Caro      Nigrán    Existente
# ..   ...        ...        ...                ...         ...          ...
# 350  304      30066   30066-C3      Mercería Coso    A Coruña    Existente
# 351  305      30066   30066-C4      Mercería Coso    A Coruña    Existente
# 352  306      30066   30066-C5  Perfumes Olorosos        Vigo    Existente
# 353  307      30066   30066-C6         El Primero        Vigo    Existente
# 354  308      30066   30066-C7      Mercería Coso    A Coruña    Existente
#
# ...

# %% [markdown]
# --------------------------------

# %% [markdown]
# Este dataframe df_completo solo debe tener como índice el ID Factura.
# -------

# %%
df_completo.set_index(['ID_Factura'], inplace=True)
df_completo.index
# Out:
# Index(['56904-C1', '56904-C2', '56904-C3', '56904-C4', '56904-C5', '56904-C6',
#        '84698-C1', '14325-C1', '14325-C2', '14325-C3',
#        ...
#        '11542-C8', '11542-C9', '11542-C10', '30066-C1', '30066-C2', '30066-C3',
#        '30066-C4', '30066-C5', '30066-C6', '30066-C7'],
#       dtype='object', name='ID_Factura', length=355)

# %% [markdown]
# -------------

# %% [markdown]
# No debe figurar el Comercio, ya que no le aporta información. Tampoco debe figurar otra información que sea redundante. Ni la fecha de compra
# -----------

# %%
df_completo.drop(columns=['Supermercado', 'Fecha'], inplace=True)
df_completo
# Out:
#              ID  ID_Pedido      Ciudad Tipo_cliente    Sexo  \
# ID_Factura
# 56904-C1      1      56904        Vigo    Existente   Mujer
# 56904-C2      2      56904  Pontevedra    Existente   Mujer
# 56904-C3      3      56904        Vigo    Existente   Mujer
# 56904-C4      4      56904        Vigo    Existente   Mujer
# 56904-C5      5      56904      Nigrán    Existente   Mujer
# ...         ...        ...         ...          ...     ...
# 30066-C3    304      30066    A Coruña    Existente  Hombre
# 30066-C4    305      30066    A Coruña    Existente  Hombre
# 30066-C5    306      30066        Vigo    Existente  Hombre
# 30066-C6    307      30066        Vigo    Existente  Hombre
# 30066-C7    308      30066    A Coruña    Existente  Hombre
#
#                    Linea_negocio  Precio_unitario  Cantidad     Total  \
# ID_Factura
# 56904-C1    Belleza y perfumería          431.570        42  18125.90
# 56904-C2            Supermercado          427.754        32  13688.10
# ...

# %% [markdown]
# --------

# %% [markdown]
# ### Tampoco se quiere guardar la Fecha de compra, no será usada.

# %%
df_completo.drop(columns='Fecha', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_completo.drop(columns='Fecha', inplace=True)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
# ...

# %% [markdown]
# ----------

# %% [markdown]
# ### Se deben preprocesar los datos para dotar a la información de calidad. Incluye tratamiento de nulos o duplicados, por ejemplo.

# %%
# habria que mirar los nulos que hay 

df_completo['Tipo_cliente'].fillna(df_completo['Tipo_cliente'].mode()[0], inplace=True)
df_completo['Sexo'].fillna('Desconocido', inplace=True)
df_completo['Precio_unitario'].fillna(df_completo['Precio_unitario'].astype(float).median(), inplace=True)
df_completo["Total"] = df_completo["Total"].fillna(df_completo["Precio_unitario"] * df_completo["Cantidad"])
# em este caso para el IVA hacemos dropna porque son menos del 5% :D
df_completo = df_completo.dropna(subset=["IVA"])
df_completo = df_completo.dropna(subset=["Precio_unitario"])
df_completo['email'].fillna('Desconocido', inplace=True)
# Duplicados
duplicados = df_completo.duplicated().sum()
df_completo.drop_duplicates(inplace=True)
df_completo.isnull().sum()

# %% [markdown]
# -------------------------

# %% [markdown]
# ### Datos Categoricos
# Además de realizar consultas sobre la información, algunos usuarios alimentarán algoritmos
# de Machine Learning con estos datos, con lo que debes preparar de forma oportuna lo
# datos categóricos. No es necesario que los normalices. Son las columnas de Ciudad, Tipo  e
# cliente, Sexo, Línea de negocio, Pago y Tipo de entrega

# %%
columnas_categoricas = [
    "Ciudad", "Tipo_cliente", "Sexo",
    "Linea_negocio", "Pago", "tipo_entrega"
]

df_encoded = pd.get_dummies(df_completo, columns=columnas_categoricas, drop_first=True)
df_encoded.head()

# %% [markdown]
# -----------------

# %% [markdown]
# **Establecer el ID_Factura como índice**

# %%
#ya preiamente se habia hhco nel indice 
df_completo.head()

# %% [markdown]
# -----------

# %% [markdown]
# ## VISUALIZAR GRÁFICOS

# %% [markdown]
# ----------------

# %%
# --- GRÁFICO 1: Distribución de Ventas Totales (Histograma) ---
plt.figure(figsize=(10, 5))
sns.histplot(df_completo['Total'], kde=True, color='blue')
plt.title('Distribución de Importes Totales de Venta')
plt.xlabel('Importe (€)')
plt.ylabel('Frecuencia')
plt.show()
print("CONCLUSIÓN 1: La mayoría de las ventas se concentran en importes bajos/medios...")
# Out:
# CONCLUSIÓN 1: La mayoría de las ventas se concentran en importes bajos/medios...

# %% [markdown]
# # GRÁFICA 2

# %%
# --- GRÁFICO 2: Ventas por Línea de Negocio (Barras) ---
plt.figure(figsize=(10, 5))
sns.countplot(data=df_completo, x='Linea_negocio', palette='viridis') 
plt.title('Número de Ventas por Línea de Negocio')
plt.xticks(rotation=45)
plt.show()
print("CONCLUSIÓN 2: Se observa qué sector tiene mayor volumen...")
# Out:
# /tmp/ipykernel_5168/976631033.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_completo, x='Linea_negocio', palette='viridis')
# CONCLUSIÓN 2: Se observa qué sector tiene mayor volumen...

# %% [markdown]
# # GRÁFICA 3

# %%
# --- GRÁFICO 3: Proporción por Sexo (Pastel) ---
plt.figure(figsize=(6, 6))
df_completo['Sexo'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'])
plt.title('Distribución de Ventas por Sexo')
plt.ylabel('')
plt.show()
print("CONCLUSIÓN 3: Muestra si existe un desequilibrio demográfico...")
# Out:
# CONCLUSIÓN 3: Muestra si existe un desequilibrio demográfico...

# %% [markdown]
# # GRÁFICA 4

# %%
# --- GRÁFICO 4: Relación Cantidad vs Total (Scatter Plot) ---
# CORRECCIÓN: 'Tipo_cliente' (con guion bajo)
plt.figure(figsize=(10, 5))
sns.scatterplot(data=df_completo, x='Cantidad', y='Total', hue='Tipo_cliente')
plt.title('Relación entre Cantidad de Productos y Total de Venta')
plt.show()
print("CONCLUSIÓN 4: Existe una correlación lineal positiva clara...")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 # --- GRÁFICO 4: Relación Cantidad vs Total (Scatter Plot) ---
#       2 # CORRECCIÓN: 'Tipo_cliente' (con guion bajo)
#       3 plt.figure(figsize=(10, 5))
# ----> 4 sns.scatterplot(data=df_completo, x='Cantidad', y='Total', hue='Tipo_cliente')
#       5 plt.title('Relación entre Cantidad de Productos y Total de Venta')
#       6 plt.show()
#
# File /opt/conda/lib/python3.11/site-packages/seaborn/relational.py:624, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     621 color = kwargs.pop("color", None)
#     622 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 624 p.plot(ax, kwargs)
#     626 return ax
#
# ...

# %% [markdown]
# # GRÁFICA 5

# %%
# --- GRÁFICO 5: Total Gastado por Tipo de Pago (Boxplot) ---
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_completo, x='Pago', y='Total')
plt.title('Distribución del Gasto según Método de Pago')
plt.show()
print("CONCLUSIÓN 5: Permite ver si ciertos métodos de pago...")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 # --- GRÁFICO 5: Total Gastado por Tipo de Pago (Boxplot) ---
#       2 plt.figure(figsize=(10, 5))
# ----> 3 sns.boxplot(data=df_completo, x='Pago', y='Total')
#       4 plt.title('Distribución del Gasto según Método de Pago')
#       5 plt.show()
#
# File /opt/conda/lib/python3.11/site-packages/seaborn/categorical.py:1619, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1612 color = _default_color(
#    1613     ax.fill_between, hue, color,
#    1614     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1615     saturation=saturation,
#    1616 )
# ...
