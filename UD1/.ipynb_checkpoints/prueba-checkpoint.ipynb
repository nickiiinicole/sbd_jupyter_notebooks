# %% [markdown]
# ### esto es una prueba

# %%
print("holaaa")
# Out:
# holaaa

# %% [markdown]
# esto es un texto **NEGRITA**

# %% [markdown]
# # JESUS BOLUDO

# %% [markdown]
# 1. boludo 1 : jesus
# 2. boluda 2 : daiara
# 3. boluda 3 : nicki
#     1. boludos clases
