# %%
# !scrapy startproject pasteleria_scrapper
# Out:
# Error: scrapy.cfg already exists in /home/jovyan/work/UD1/pasteleria_scrapper

# %%
# %cd pasteleria_scrapper
# Out:
# /home/jovyan/work/UD1/pasteleria_scrapper

# %%
# !scrapy genspider pasteleria elatelierdediegocaride.com/15-pasteles
# Out:
# Spider 'pasteleria' already exists in module:
#   pasteleria_scrapper.spiders.pasteleria

# %%
# !scrapy crawl pasteleria -o resultado.json > log.txt 2>&1
