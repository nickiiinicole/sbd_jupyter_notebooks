# %% [markdown]
# ### Proyect Profe con Scrapy

# %% [markdown]
# IMPORTANTE:
# 0. Los ejemplos tienen que ser con HTML estático y poco JS .
# 1. Aunque podemos hacer scrapy en páginas con JS, necesitaríamos herramientas adicionales como **Playwrigth** pero se nos iría de las manos la UD.
# 2. Para elegir una web adecuaado hay un pequeño truco: abrir la página con el contenido que queremos obtener, por ejemplo precios o stock, etc.. y con botón derecho VER CÓDIGO FUENTE DE LA PÁGINA, y si ya no aparece nada es que no es html estático y poco podemos hacer. En caso contrario, si podremos hacer scrapy.
# 3. En el ejemplo siguiente, www.lboutique.es, una tienda de ropa de Vigo, si hacemos ver código fuente, nos aparece información de los artículos, es buena señal.

# %% [raw]
# <article
#                 class="product-miniature product-miniature-default product-miniature-grid product-miniature-layout-1 js-product-miniature"
#                 data-id-product="870"
#                 data-id-product-attribute="7052"
#         >
#     <div class="thumbnail-container">
#         <a href="https://lboutique.es/inicio/870-7052-vestido-midi-avery-0000000000808.html#/32-tallas_numeros-36/83-color-verde_pastel" class="thumbnail product-thumbnail">
#                             <img data-src="https://lboutique.es/2930-home_default/vestido-midi-avery.jpg" src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 450 594'%3E%3C/svg%3E"
#                                                 alt="VESTIDO MIDI AVERY"
#                         data-full-size-image-url="https://lboutique.es/2930-thickbox_default/vestido-midi-avery.jpg"
#                         width="450"
#                         height="594"
#                         class="img-fluid swiper-lazy lazy-product-image product-thumbnail-first  "                >                                                                                                                                             <img
#                                 src="data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' viewBox='0 0 450 594'%3E%3C/svg%3E"
#                                 data-src="https://lboutique.es/2931-home_default/vestido-midi-avery.jpg"
#                                 width="450"
#                                 height="594"
#                                 alt="VESTIDO MIDI AVERY 2"
#                                 class="img-fluid swiper-lazy lazy-product-image product-thumbnail-second"
#                             >
#                                                                 </a>
#
#             <ul class="product-flags js-product-flags">
#                             </ul>
#             <div class="product-functional-buttons product-functional-buttons-bottom">
#                 <div class="product-functional-buttons-links">
#                     <a href="#" class="btn-iqitwishlist-add js-iqitwishlist-add"  data-id-product="870" data-id-product-attribute="7052"
#    data-url="//lboutique.es/module/iqitwishlist/actions" data-toggle="tooltip" title="Add to wishlist">
#     <i class="fa fa-heart-o not-added" aria-hidden="true"></i> <i class="fa fa-heart added" aria-hidden="true"></i>
# </a>
# <a href="#" class="btn-iqitcompare-add js-iqitcompare-add"  data-id-product="870"
#    data-url="//lboutique.es/module/iqitcompare/actions" data-toggle="tooltip" title="Compare">
#     <i class="fa fa-random" aria-hidden="true"></i>
# </a>
#
#                         <a class="js-quick-view-iqit" href="#" data-link-action="quickview" data-toggle="tooltip"
#                            title="Vista Rápida">
#                             <i class="fa fa-eye" aria-hidden="true"></i></a>
#
#                 </div>
#             </div>
#             <div class="product-availability d-block">
#
#                     <span
#                             class="badge  badge-success product-available mt-2">
#                                         <i class="fa fa-check rtl-no-flip" aria-hidden="true"></i>
#                                                      Stock disponible
#                                   </span>
#                  </div>
#     </div>
# <div class="product-description">
#
#                     <div class="product-category-name text-muted">Inicio</div>
#
#         <h2 class="h3 product-title">
#             <a href="https://lboutique.es/inicio/870-7052-vestido-midi-avery-0000000000808.html#/32-tallas_numeros-36/83-color-verde_pastel">VESTIDO MIDI AVERY</a>
#         </h2>
#         <div class="product-reference text-muted"> <a href="https://lboutique.es/inicio/870-7052-vestido-midi-avery-0000000000808.html#/32-tallas_numeros-36/83-color-verde_pastel">RF0000808</a></div>
#       <div class="product-price-and-shipping">
#
#                 <a href="https://lboutique.es/inicio/870-7052-vestido-midi-avery-0000000000808.html#/32-tallas_numeros-36/83-color-verde_pastel"> <span  class="product-price" content="125.9" aria-label="Precio">
#                                                                             125,90 €      </span></a>
#             </div>
#                     <div class="products-variants">
#                                     <div class="variant-links">
#             <a href="https://lboutique.es/inicio/870-7051-vestido-midi-avery-0000000000808.html#/18-color-rosa_palo/32-tallas_numeros-36"
#            class="color"   title="Rosa Palo"        aria-label="Rosa Palo"              style="background-color: #FCCACD"         ></a>
#             <a href="https://lboutique.es/inicio/870-7052-vestido-midi-avery-0000000000808.html#/32-tallas_numeros-36/83-color-verde_pastel" class="color"    title="Verde Pastel"   aria-label="Verde Pastel"
#                  style="background-color: #60ff98"         ></a>
#         <span class="js-count count"></span>   </div>
#                             </div>
#         <div class="product-description-short text-muted">
#             <a href="https://lboutique.es/inicio/870-7052-vestido-midi-avery-0000000000808.html#/32-tallas_numeros-36/83-color-verde_pastel">
# COLECCIÓN INVITADA PERFECTA
# Vestido de fiesta largo midi con escote a pico con tul transparente, manga francesa, detalle de flor y abertura a un lado.
# ----------
# Si tienes alguna duda cuentas con una Guía de tallas a continuación además  de un servicio de atención personaliza a través de nuestro WhatsApp 691 855 273
# </a>
#         </div>
#         <div class="product-add-cart js-product-add-cart-870-7052" >
#             <form action="https://lboutique.es/carrito?add=1&amp;id_product=870&amp;id_product_attribute=7052&amp;token=dc70acf635f8728d8be54599b9d1b951" method="post">
#
#             <input type="hidden" name="id_product" value="870">
#             <div class="input-group-add-cart">
#                 <input
#                         type="number"
#                         name="qty"
#                         value="1"
#                         class="form-control input-qty"
#                         min="1"
#                         max="1"                >
#
#                 <button
#                         class="btn btn-product-list add-to-cart"
#                         data-button-action="add-to-cart"
#                         type="submit"
#                                         ><i class="fa fa-shopping-bag fa-fw bag-icon"
#                     aria-hidden="true"></i> <i class="fa fa-circle-o-notch fa-spin fa-fw spinner-icon" aria-hidden="true"></i> Añadir al carrito
#                 </button>
#             </div>
#         </form>
#     </div>
#               <div class="iqitsizeguide-avaiable-sizes pt-2">
#             <span >Rosa Palo</span>
#             <span >Verde Pastel</span>
#             <span >36</span>
#             <span >38</span>
#             <span class="unavailable-size">40</span>
#             <span class="unavailable-size">42</span>
#             <span class="unavailable-size">44</span>
#             <span class="unavailable-size">46</span>
#             <span >48</span>
#             <span class="unavailable-size">50</span>
#         </div>
# </div>

# %% [markdown]
# Vamos creando el proyecto

# %%
# !scrapy startproject boutique_scraper
# Out:
# New Scrapy project 'boutique_scraper', using template directory '/opt/conda/lib/python3.11/site-packages/scrapy/templates/project', created in:
#     /home/jovyan/work/UD1/boutique_scraper
#
# You can start your first spider with:
#     cd boutique_scraper
#     scrapy genspider example example.com

# %%
# %cd boutique_scraper
# Out:
# /home/jovyan/work/UD1/boutique_scraper

# %%
# !scrapy genspider boutique lboutique.es
# Out:
# Spider 'boutique' already exists in module:
#   boutique_scraper.spiders.boutique

# %%
# !scrapy crawl boutique -o resultados.json   > log.txt 2>&1

# %% [markdown]
# ### NOTA CÓDIGO DEL SPIDER  ###

# %% [raw]
# import scrapy
#
# class BoutiqueSpider(scrapy.Spider):
#     name = "boutique"
#     allowed_domains = ["lboutique.es"]
#     start_urls = ["https://lboutique.es/"]  # Ajusta si quieres otra categoría
#
#     def parse(self, response):
#         productos = response.css("article.product-miniature")
#
#         for producto in productos:
#             nombre = producto.css("h2.product-title a::text").get()
#             precio = producto.css("span.product-price::text").get()
#             disponibilidad = (
#                 producto.css("span.product-available::text").get()
#                 or producto.css("span.product-unavailable::text").get()
#             )
#
#             yield {
#                 "nombre": nombre.strip(),
#                 "precio": precio.strip(),
#                 "disponibilidad": disponibilidad.strip(),
#             }
#
#         # Paginación
#         siguiente = response.css("ul.pagination a.next::attr(href)").get()
#         if siguiente:
#             yield response.follow(siguiente, self.parse)
