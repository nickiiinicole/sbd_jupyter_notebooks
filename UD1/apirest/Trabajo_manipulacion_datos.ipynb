# %% [markdown]
# # Proyecto de Sistemas de Big Data:D
# **Autores:** Nicole Díaz y Enrique Ángel

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_completo = pd.read_csv("dataset_ventas.csv",encoding="latin-1")
df_completo
# Out:
#                                              ID Pedido  \
# 0    #El siguiente dataset contiene las ventas del ...
# 1    #Cada pedido puede incluir compras a distintos...
# 2    ######################Inicio del resumen de co...
# 3                                                56904
# 4                                                56904
# ..                                                 ...
# 307                                              30066
# 308                                              30066
# 309                                              30066
# 310                                              30066
# 311  ######################Fin del resumen de compr...
#
#                                             ID Factura           Comercio  \
# 0                                                  NaN                NaN
# 1     por lo que cada uno tiene su propio ID de fac...                NaN
# 2                                                  NaN                NaN
# ...

# %%
df_completo_dir = pd.read_csv("DIRECCIONES.csv",encoding="latin-1")
df_completo_dir

# %%
# df_completo['Codigo Postal'] =

# %%
df_completo['Tipo de Entrega']
