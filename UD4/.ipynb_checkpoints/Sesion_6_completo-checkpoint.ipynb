# %% [markdown]
# # Sesion 6 MongoDb
# Curso de Especialización en Inteligencia Artificial y Big Data
# Profesor: Juan Carlos Pérez González
# Departamento de Informática – IES de Teis

# %% [markdown]
# **Conexión a Servidor MongoDB (contenedor)**

# %%
# Instalar pymongo si no está disponible
import subprocess
import sys

try:
    import pymongo
    print(f"pymongo versión {pymongo.__version__} ya está instalado")
except ImportError:
    print("Instalando pymongo...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "pymongo"])
    print("pymongo instalado correctamente")
# Out:
# pymongo versión 4.15.5 ya está instalado

# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

# Conexión a MongoDB (usando localhost y el puerto mapeado)
try:
    client = MongoClient('mongodb://172.18.0.5:27017/')     #dende Compass con localhost e o porto exposto no docker

# Verificar la conexión
    print(client.list_database_names())  # Esto debería mostrar las bases de datos existentes
    print("conexion realizada")
except ConnectionFailure:
    print ("conexión errónea")
# Out:
# ['admin', 'config', 'database', 'local']
# conexion realizada

# %% [markdown]
# **Creación de una base de datos**

# %%
# Conexión al cliente MongoDB
db = client["database"]  # Aquí se crea o selecciona la base de datos

# Seleccionar o crear la colección
coleccion = db["usuarios"]  # La colección "usuarios"

# Documento a insertar
usuario = {
    "nombre": "Maria Sol",
    "email": "maria@example.com",
    "edad": 42
}

# Insertar el documento
resultado = coleccion.insert_one(usuario)
print(f"Documento insertado con ID: {resultado.inserted_id}")

# Verificar que la base de datos y la colección existen
print("Bases de datos en el servidor:", client.list_database_names())
print("Colecciones en la base de datos:", db.list_collection_names())
# Out:
# Documento insertado con ID: 6964e69e142c03434e83b8fc
# Bases de datos en el servidor: ['admin', 'config', 'database', 'local']
# Colecciones en la base de datos: ['empleados', 'usuarios']

# %%
usuarios = [
    {"nombre": "Sonia Ruiz", "email": "sonia@example.com", "edad": 28},
    {"nombre": "Luis Blanco", "email": "luis@example.com", "edad": 40},
    {"nombre": "Marta Pérez", "email": "marta@example.com", "edad": 22}
]

# Insertar varios documentos a la vez
resultado = coleccion.insert_many(usuarios)

# Imprimir los IDs generados
print("Documentos insertados con IDs:", resultado.inserted_ids)
# Out:
# Documentos insertados con IDs: [ObjectId('6964e69e142c03434e83b8fd'), ObjectId('6964e69e142c03434e83b8fe'), ObjectId('6964e69e142c03434e83b8ff')]

# %% [markdown]
# **Consultas simples**

# %%
#IMPORTANTE DB SIEMPRE DELANTE
for doc in db.usuarios.find():
    print(doc)
# Out:
# {'_id': ObjectId('6964e51830ca5b4b7241d860'), 'fullname': 'Nuevo Usuario', 'email': 'maria@example.com'}
# {'_id': ObjectId('6964e69e142c03434e83b8fc'), 'nombre': 'Maria Sol', 'email': 'maria@example.com', 'edad': 42}
# {'_id': ObjectId('6964e69e142c03434e83b8fd'), 'nombre': 'Sonia Ruiz', 'email': 'sonia@example.com', 'edad': 28}
# {'_id': ObjectId('6964e69e142c03434e83b8fe'), 'nombre': 'Luis Blanco', 'email': 'luis@example.com', 'edad': 40}
# {'_id': ObjectId('6964e69e142c03434e83b8ff'), 'nombre': 'Marta Pérez', 'email': 'marta@example.com', 'edad': 22}

# %% [markdown]
# **Consultas por campos**

# %%
# Por un campo

for doc in db.usuarios.find({"edad": {"$gt": 30}}):
    print(doc)
# Out:
# {'_id': ObjectId('6964e69e142c03434e83b8fc'), 'nombre': 'Maria Sol', 'email': 'maria@example.com', 'edad': 42}
# {'_id': ObjectId('6964e69e142c03434e83b8fe'), 'nombre': 'Luis Blanco', 'email': 'luis@example.com', 'edad': 40}

# %%
# Solo algunos campos

for doc in db.usuarios.find({"edad": {"$gt": 30}}, {"nombre": 1, "_id": 0}):
    print(doc)
# Out:
# {'nombre': 'Maria Sol'}
# {'nombre': 'Luis Blanco'}

# %% [markdown]
# IMPORTANTE:
#
# $eq → igual a un valor.
#
# $ne → distinto de un valor.
#
# $gt → mayor que un valor.
#
# $gte → mayor o igual que un valor.
#
# $lt → menor que un valor.
#
# $lte → menor o igual que un valor.
#
# $in → dentro de una lista de valores.
#
# $nin → no dentro de una lista de valores.
#
# $or → o lógico.
#
# $not → negación.
#
# $nor → “ni… ni…”.
#
# $exists → si un campo existe.
#
# $type → filtrar por tipo de dato (int, string, bool, etc.).
#
# $size → tamaño de un array.
#
# $all → contiene todos los valores especificados.
#
# $elemMatch → coincidencia de elementos en arrays con condiciones.

# %%
# 1.Usuarios cuyo nombre sea Juan o Ana
print("\nUsuarios Juan o Ana:")
for doc in db.usuarios.find({"nombre": {"$in": ["Juan Carlos", "Ana"]}}):
    print(doc)

# 2. Usuarios que NO tengan email definido
print("\n Usuarios sin email:")
for doc in db.usuarios.find({"email": {"$exists": False}}):
    print(doc)
# Out:
# Usuarios Juan o Ana:
#
#  Usuarios sin email:

# %% [markdown]
# **Añadir Campos**

# %%
# Añadir un campo 'intereses' vacío a todos los usuarios
db.usuarios.update_many({}, {"$set": {"intereses": []}})

# Verificar los cambios
for doc in db.usuarios.find():
    print(doc)
# Out:
# {'_id': ObjectId('6964e51830ca5b4b7241d860'), 'fullname': 'Nuevo Usuario', 'email': 'maria@example.com', 'intereses': []}
# {'_id': ObjectId('6964e69e142c03434e83b8fc'), 'nombre': 'Maria Sol', 'email': 'maria@example.com', 'edad': 42, 'intereses': []}
# {'_id': ObjectId('6964e69e142c03434e83b8fd'), 'nombre': 'Sonia Ruiz', 'email': 'sonia@example.com', 'edad': 28, 'intereses': []}
# {'_id': ObjectId('6964e69e142c03434e83b8fe'), 'nombre': 'Luis Blanco', 'email': 'luis@example.com', 'edad': 40, 'intereses': []}
# {'_id': ObjectId('6964e69e142c03434e83b8ff'), 'nombre': 'Marta Pérez', 'email': 'marta@example.com', 'edad': 22, 'intereses': []}

# %% [markdown]
# **Actualizar campos**

# %%
db.usuarios.update_one(
    {"nombre": "Juan Carlos"},
    {"$set": {"intereses": ["Python", "Big Data"]}}
)

# Consultar ese usuario
print(db.usuarios.find_one({"nombre": "Juan Carlos"}))
# Out:
# None

# %%
#añadir un campo activo
db.usuarios.update_many({}, {"$set": {"activo": True}})
# Out:
# UpdateResult({'n': 5, 'nModified': 5, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Verificar los cambios
for doc in db.usuarios.find():
    print(doc)
# Out:
# {'_id': ObjectId('6964e51830ca5b4b7241d860'), 'fullname': 'Nuevo Usuario', 'email': 'maria@example.com', 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fc'), 'nombre': 'Maria Sol', 'email': 'maria@example.com', 'edad': 42, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fd'), 'nombre': 'Sonia Ruiz', 'email': 'sonia@example.com', 'edad': 28, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fe'), 'nombre': 'Luis Blanco', 'email': 'luis@example.com', 'edad': 40, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8ff'), 'nombre': 'Marta Pérez', 'email': 'marta@example.com', 'edad': 22, 'intereses': [], 'activo': True}

# %% [markdown]
# **Busquedas Avanzadas**

# %%
# por igualdad

for doc in db.usuarios.find({"edad": 35}):
    print(doc)

# %%
# por comparación
# mayoor qué

for doc in db.usuarios.find({"edad": {"$gt": 40}}):
    print(doc)

#menor que

for doc in db.usuarios.find({"edad": {"$lt": 30}}):
    print(doc)

#mayor y menor o igual

for doc in db.usuarios.find({"edad": {"$gte": 30, "$lte": 40}}):
    print(doc)
# Out:
# {'_id': ObjectId('6964e69e142c03434e83b8fc'), 'nombre': 'Maria Sol', 'email': 'maria@example.com', 'edad': 42, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fd'), 'nombre': 'Sonia Ruiz', 'email': 'sonia@example.com', 'edad': 28, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8ff'), 'nombre': 'Marta Pérez', 'email': 'marta@example.com', 'edad': 22, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fe'), 'nombre': 'Luis Blanco', 'email': 'luis@example.com', 'edad': 40, 'intereses': [], 'activo': True}

# %%
# varios campos como AND o BUSQUEDA COMBINADA

query = {"edad": {"$gt": 30}, "nombre": "Luis Blanco"}
for doc in db.usuarios.find(query):
    print(doc)
# Out:
# {'_id': ObjectId('6964e69e142c03434e83b8fe'), 'nombre': 'Luis Blanco', 'email': 'luis@example.com', 'edad': 40, 'intereses': [], 'activo': True}

# %%
# valores dentro de una lista

for doc in db.usuarios.find({"edad": {"$in": [22, 28]}}):
    print(doc)
# Out:
# {'_id': ObjectId('6964e69e142c03434e83b8fd'), 'nombre': 'Sonia Ruiz', 'email': 'sonia@example.com', 'edad': 28, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8ff'), 'nombre': 'Marta Pérez', 'email': 'marta@example.com', 'edad': 22, 'intereses': [], 'activo': True}

# %%
# valores regulares  en este caso que empiecen pr M

for doc in db.usuarios.find({"nombre": {"$regex": "^M", "$options": "i"}}):
    print(doc)
# Out:
# {'_id': ObjectId('6964e69e142c03434e83b8fc'), 'nombre': 'Maria Sol', 'email': 'maria@example.com', 'edad': 42, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8ff'), 'nombre': 'Marta Pérez', 'email': 'marta@example.com', 'edad': 22, 'intereses': [], 'activo': True}

# %%
# seleccionar algunos campos 

for doc in db.usuarios.find({}, {"_id": 0, "nombre": 1, "edad": 1}):
    print(doc)
# Out:
# {}
# {'nombre': 'Maria Sol', 'edad': 42}
# {'nombre': 'Sonia Ruiz', 'edad': 28}
# {'nombre': 'Luis Blanco', 'edad': 40}
# {'nombre': 'Marta Pérez', 'edad': 22}

# %%
#ordenando

for doc in db.usuarios.find().sort("edad", 1):  # 1 ascendente, -1 descendente
    print(doc)
# Out:
# {'_id': ObjectId('6964e51830ca5b4b7241d860'), 'fullname': 'Nuevo Usuario', 'email': 'maria@example.com', 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8ff'), 'nombre': 'Marta Pérez', 'email': 'marta@example.com', 'edad': 22, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fd'), 'nombre': 'Sonia Ruiz', 'email': 'sonia@example.com', 'edad': 28, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fe'), 'nombre': 'Luis Blanco', 'email': 'luis@example.com', 'edad': 40, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fc'), 'nombre': 'Maria Sol', 'email': 'maria@example.com', 'edad': 42, 'intereses': [], 'activo': True}

# %%
# limitar resultados
for doc in db.usuarios.find().limit(3):
    print(doc)
# Out:
# {'_id': ObjectId('6964e51830ca5b4b7241d860'), 'fullname': 'Nuevo Usuario', 'email': 'maria@example.com', 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fc'), 'nombre': 'Maria Sol', 'email': 'maria@example.com', 'edad': 42, 'intereses': [], 'activo': True}
# {'_id': ObjectId('6964e69e142c03434e83b8fd'), 'nombre': 'Sonia Ruiz', 'email': 'sonia@example.com', 'edad': 28, 'intereses': [], 'activo': True}

# %% [markdown]
# **EJERCICIOS**
#
# Antes de avanzar te propongo estos ejercicios:
#
# 1. Buscar usuarios mayores de 40.
# 2. Buscar todos los que empiecen por la letra L.
# 3. Listar solo nombre y correo, ordenados por edad.
# 4. Buscar entre edades 30–50.
# 5. Hacer una búsqueda combinada:
# - edad > 30
# - nombre que empiece por M

# %% [markdown]
# **Actualizaciones avanzadas**

# %%
#empezamos por algo sencillo busca el resultado en COMPAss

db.usuarios.update_one(
    {"nombre": "Juan Carlos"},
    {"$set": {"edad": 36}}
)

print(list(db.usuarios.find({"nombre": "Juan Carlos"})))
# Out:
# []

# %%
#actuializar varios usuarios subiéndoles un año

db.usuarios.update_many(
    {"edad": {"$gt": 30}},
    {"$inc": {"edad": 1}}
)
# Out:
# UpdateResult({'n': 2, 'nModified': 2, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
#eliminar un campo

db.usuarios.update_many(
    {},
    {"$unset": {"email": ""}}
)
# Out:
# UpdateResult({'n': 5, 'nModified': 5, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
#renombrar un campo

db.usuarios.update_many(
    {},
    {"$rename": {"nombre": "fullname"}}
)
# Out:
# UpdateResult({'n': 5, 'nModified': 4, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
#actualizar un usuarios específico

db.usuarios.update_one(
    {"fullname": "Marta Pérez"},
    {
        "$set": {"edad": 23, "activo": False},
        "$inc": {"puntos": 10}
    }
)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# **EJERCICIOS**
#
# 1. Añade el campo rol con valor usuario a todos los documentos de la colección usuarios
# 2. Añadel el campo puntos con +20 al usuario Luis Angel
# 3. Añade el campo email a Marta Pérez con marta@mail.com y un campo premium: true
# 4. Añade al mismo usuario Marta Pérez un campo intereses con JavaScript y Docker

# %% [markdown]
# **Eliminaciones**

# %%
# Borra un usuario específico por nombre
resultado = coleccion.delete_one({"fullname": "Luis Blanco"})
print(f"Documentos eliminados: {resultado.deleted_count}")
# Out:
# Documentos eliminados: 1

# %%
# Borra todos los usuarios que no estén activos
resultado = coleccion.delete_many({"activo": False})
print(f"Documentos eliminados: {resultado.deleted_count}")
# Out:
# Documentos eliminados: 1

# %%
# Vaciar la colección
resultado = coleccion.delete_many({})
print(f"Documentos eliminados: {resultado.deleted_count}")
# Out:
# Documentos eliminados: 3

# %% [markdown]
# **Índices**
#
# Los índices son estructuras de datos que mejoran el rendimiento de las consultas. Sin índices, MongoDB debe escanear todos los documentos (collection scan). Con índices, accede directamente a los documentos que coinciden.

# %%
# Crear un índice simple en el campo 'edad'
db.usuarios.create_index([("edad", 1)])  # 1 = ascendente, -1 = descendente
print("Índice en 'edad' creado")

# Listar todos los índices en la colección
indices = db.usuarios.list_indexes()
for indice in indices:
    print(indice)
# Out:
# Índice en 'edad' creado
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
# SON([('v', 2), ('key', SON([('edad', 1)])), ('name', 'edad_1')])

# %%
# Índice compuesto (múltiples campos)
db.usuarios.create_index([("edad", 1), ("fullname", 1)])
print("Índice compuesto en 'edad' y 'fullname' creado")
# Out:
# Índice compuesto en 'edad' y 'fullname' creado

# %%
# Índice único (no permite valores duplicados)
db.usuarios.create_index([("email", 1)], unique=True)
print("Índice único en 'email' creado")

# Intentar insertar un email duplicado (generará error)
try:
    db.usuarios.insert_one({"fullname": "Nuevo Usuario", "email": "maria@example.com"})
except Exception as e:
    print(f"Error al insertar duplicado: {e}")
# Out:
# Índice único en 'email' creado

# %%
# Índice de texto (búsqueda por palabras)
db.usuarios.create_index([("fullname", "text"), ("email", "text")])
print("Índice de texto creado")

# Buscar documentos con texto
for doc in db.usuarios.find({"$text": {"$search": "Maria"}}):
    print(doc)
# Out:
# Índice de texto creado
# {'_id': ObjectId('6964e69e142c03434e83b900'), 'fullname': 'Nuevo Usuario', 'email': 'maria@example.com'}

# %% [markdown]
# **Información sobre índices y borrado**

# %%
# Borrar un índice específico
db.usuarios.drop_index([("edad", 1)])
print("Índice en 'edad' eliminado")

# Borrar todos los índices (excepto el _id que es obligatorio)
db.usuarios.drop_indexes()
print("Todos los índices eliminados (excepto _id)")
# Out:
# Índice en 'edad' eliminado
# Todos los índices eliminados (excepto _id)

# %% [markdown]
# **Tipos de Índices - Resumen**
#
# | Tipo | Uso | Sintaxis |
# |------|-----|---------|
# | **Simple** | Campo único | `create_index([("campo", 1)])` |
# | **Compuesto** | Múltiples campos | `create_index([("campo1", 1), ("campo2", 1)])` |
# | **Único** | Sin duplicados | `create_index([("campo", 1)], unique=True)` |
# | **Texto** | Búsqueda por palabras | `create_index([("campo", "text")])` |
# | **TTL** | Expiración automática | `create_index([("fecha", 1)], expireAfterSeconds=3600)` |
# | **Geoespacial** | Coordenadas | `create_index([("ubicacion", "2dsphere")])` |

# %% [markdown]
# **EJERCICIOS - Índices**
#
# 1. Crea un índice en el campo `edad` y lista todos los índices.
# 2. Crea un índice compuesto en `edad` y `fullname`.
# 3. Crea un índice único en `email` e intenta insertar un email duplicado.
# 4. Crea un índice de texto en `fullname` y busca por palabra.
# 5. Borra todos los índices y verifica que solo queda el índice `_id`.

# %% [markdown]
# **CARGA DE DATOS DESDE FICHEROS**
#
# En este caso hablaremos de csv

# %%
import csv
from pymongo import MongoClient
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

# Conexión a MongoDB (usando la IP interna del contenedor: 172.18.0.3)
try:
    # Corrección: Usar la IP 172.18.0.3 que se ve en la inspección de red de Docker
    client = MongoClient('mongodb://172.18.0.5:27017/')

    print("conexion realizada")

    db = client["database"]        # Base de datos
    coleccion = db["empleados"]   # Colección

    # -------------------------------
    # 2. Leer el CSV
    # -------------------------------
    empleados = []
    with open("empresa.csv", "r", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in reader:
            # Convertir tipos (CSV son strings)
            row["id"] = int(row["id"])
            row["salario"] = int(row["salario"])
            row["activo"] = True if row["activo"] == "True" else False

            empleados.append(row)

    # -------------------------------
    # 3. Insertar en MongoDB
    # -------------------------------
    resultado = coleccion.insert_many(empleados)

    print(f"Documentos insertados: {len(resultado.inserted_ids)}")

except ConnectionFailure:
    print ("conexión errónea")
# Out:
# conexion realizada
# Documentos insertados: 1000

# %% [markdown]
# **Ejercicios**

# %% [markdown]
# **A. Consultas Básicas**
#
# 1. Obtén todos los empleados del departamento "Ventas".
# 2. Muestra únicamente los campos nombre y salario de todos los empleados.
# 3. Consulta los empleados cuyo salario sea mayor de 30000.
# 4. Filtra los empleados cuya edad esté entre 30 y 40 años, ambos inclusive.
# 5. Saca todos los empleados inactivos (activo = false).
# 6. Muestra los empleados cuyo nombre empiece por la letra A.

# %%
coleccion = db["empleados"]

# %%
print("1. Empleados del departamento 'Ventas':")
query_ventas = {"departamento": "Ventas"}
for empleado in coleccion.find(query_ventas).limit(20):
    print(empleado)
# Out:
# 1. Empleados del departamento 'Ventas':
# {'_id': ObjectId('6964e26d7370496126b61b37'), 'id': 17, 'nombre': 'María', 'apellido': 'García', 'departamento': 'Ventas', 'salario': 28140, 'fecha_contratacion': '2016-06-18', 'email': 'maría.garcía17@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b3d'), 'id': 23, 'nombre': 'Laura', 'apellido': 'Fernández', 'departamento': 'Ventas', 'salario': 44486, 'fecha_contratacion': '2021-06-16', 'email': 'laura.fernández23@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b41'), 'id': 27, 'nombre': 'Juan', 'apellido': 'García', 'departamento': 'Ventas', 'salario': 39180, 'fecha_contratacion': '2021-06-08', 'email': 'juan.garcía27@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b43'), 'id': 29, 'nombre': 'Jorge', 'apellido': 'García', 'departamento': 'Ventas', 'salario': 42154, 'fecha_contratacion': '2017-02-25', 'email': 'jorge.garcía29@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b4c'), 'id': 38, 'nombre': 'Juan', 'apellido': 'Díaz', 'departamento': 'Ventas', 'salario': 60620, 'fecha_contratacion': '2020-05-03', 'email': 'juan.díaz38@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b4e'), 'id': 40, 'nombre': 'Luis', 'apellido': 'López', 'departamento': 'Ventas', 'salario': 42622, 'fecha_contratacion': '2022-02-09', 'email': 'luis.lópez40@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b50'), 'id': 42, 'nombre': 'Luis', 'apellido': 'Gómez', 'departamento': 'Ventas', 'salario': 52721, 'fecha_contratacion': '2025-06-03', 'email': 'luis.gómez42@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b5a'), 'id': 52, 'nombre': 'Sara', 'apellido': 'García', 'departamento': 'Ventas', 'salario': 52800, 'fecha_contratacion': '2016-02-25', 'email': 'sara.garcía52@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b5e'), 'id': 56, 'nombre': 'Juan', 'apellido': 'Morales', 'departamento': 'Ventas', 'salario': 18242, 'fecha_contratacion': '2021-12-05', 'email': 'juan.morales56@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b62'), 'id': 60, 'nombre': 'Laura', 'apellido': 'López', 'departamento': 'Ventas', 'salario': 22970, 'fecha_contratacion': '2024-08-20', 'email': 'laura.lópez60@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b65'), 'id': 63, 'nombre': 'Sara', 'apellido': 'Morales', 'departamento': 'Ventas', 'salario': 30753, 'fecha_contratacion': '2021-06-27', 'email': 'sara.morales63@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b67'), 'id': 65, 'nombre': 'Laura', 'apellido': 'Díaz', 'departamento': 'Ventas', 'salario': 31966, 'fecha_contratacion': '2021-03-27', 'email': 'laura.díaz65@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b81'), 'id': 91, 'nombre': 'Carlos', 'apellido': 'García', 'departamento': 'Ventas', 'salario': 39397, 'fecha_contratacion': '2019-09-21', 'email': 'carlos.garcía91@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b90'), 'id': 106, 'nombre': 'Luis', 'apellido': 'Fernández', 'departamento': 'Ventas', 'salario': 58643, 'fecha_contratacion': '2017-11-27', 'email': 'luis.fernández106@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b93'), 'id': 109, 'nombre': 'María', 'apellido': 'Gómez', 'departamento': 'Ventas', 'salario': 54148, 'fecha_contratacion': '2022-08-31', 'email': 'maría.gómez109@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61bb0'), 'id': 138, 'nombre': 'María', 'apellido': 'Díaz', 'departamento': 'Ventas', 'salario': 30383, 'fecha_contratacion': '2023-10-07', 'email': 'maría.díaz138@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61bc2'), 'id': 156, 'nombre': 'Ana', 'apellido': 'Pérez', 'departamento': 'Ventas', 'salario': 34045, 'fecha_contratacion': '2018-03-17', 'email': 'ana.pérez156@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61bc7'), 'id': 161, 'nombre': 'Pablo', 'apellido': 'Ruiz', 'departamento': 'Ventas', 'salario': 57254, 'fecha_contratacion': '2018-01-03', 'email': 'pablo.ruiz161@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61bc8'), 'id': 162, 'nombre': 'Elena', 'apellido': 'Morales', 'departamento': 'Ventas', 'salario': 52522, 'fecha_contratacion': '2017-06-06', 'email': 'elena.morales162@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61bc9'), 'id': 163, 'nombre': 'Jorge', 'apellido': 'Pérez', 'departamento': 'Ventas', 'salario': 25214, 'fecha_contratacion': '2023-05-17', 'email': 'jorge.pérez163@empresa.com', 'activo': True}

# %%
print("\n2. Nombre y Salario de todos los empleados:")
projection_nombre_salario = {"nombre": 1, "salario": 1, "_id": 0}
for empleado in coleccion.find({}, projection_nombre_salario).limit(20):
    print(empleado)
# Out:
# 2. Nombre y Salario de todos los empleados:
# {'nombre': 'Elena', 'salario': 29761}
# {'nombre': 'María', 'salario': 49873}
# {'nombre': 'Elena', 'salario': 62033}
# {'nombre': 'Luis', 'salario': 64492}
# {'nombre': 'Ana', 'salario': 47430}
# {'nombre': 'Juan', 'salario': 43478}
# {'nombre': 'Laura', 'salario': 39677}
# {'nombre': 'Ana', 'salario': 25181}
# {'nombre': 'Laura', 'salario': 54653}
# {'nombre': 'Luis', 'salario': 60947}
# {'nombre': 'Ana', 'salario': 40526}
# {'nombre': 'Luis', 'salario': 42006}
# {'nombre': 'Laura', 'salario': 27738}
# {'nombre': 'Sara', 'salario': 24901}
# {'nombre': 'Jorge', 'salario': 64705}
# {'nombre': 'Juan', 'salario': 36350}
# {'nombre': 'María', 'salario': 28140}
# {'nombre': 'Laura', 'salario': 34694}
# {'nombre': 'María', 'salario': 32968}
# {'nombre': 'María', 'salario': 52123}

# %%
print("\n3. Empleados con salario mayor de 30000:")
query_salario_mayor = {"salario": {"$gt": 30000}}
for empleado in coleccion.find(query_salario_mayor).limit(20):
    print(empleado)
# Out:
# 3. Empleados con salario mayor de 30000:
# {'_id': ObjectId('6964e26d7370496126b61b28'), 'id': 2, 'nombre': 'María', 'apellido': 'Fernández', 'departamento': 'Logística', 'salario': 49873, 'fecha_contratacion': '2021-06-04', 'email': 'maría.fernández2@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b29'), 'id': 3, 'nombre': 'Elena', 'apellido': 'Fernández', 'departamento': 'RRHH', 'salario': 62033, 'fecha_contratacion': '2016-05-11', 'email': 'elena.fernández3@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b2a'), 'id': 4, 'nombre': 'Luis', 'apellido': 'Pérez', 'departamento': 'IT', 'salario': 64492, 'fecha_contratacion': '2018-06-17', 'email': 'luis.pérez4@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b2b'), 'id': 5, 'nombre': 'Ana', 'apellido': 'Fernández', 'departamento': 'RRHH', 'salario': 47430, 'fecha_contratacion': '2023-08-02', 'email': 'ana.fernández5@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b2c'), 'id': 6, 'nombre': 'Juan', 'apellido': 'Martínez', 'departamento': 'Producción', 'salario': 43478, 'fecha_contratacion': '2020-08-29', 'email': 'juan.martínez6@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b2d'), 'id': 7, 'nombre': 'Laura', 'apellido': 'Pérez', 'departamento': 'RRHH', 'salario': 39677, 'fecha_contratacion': '2017-09-22', 'email': 'laura.pérez7@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b2f'), 'id': 9, 'nombre': 'Laura', 'apellido': 'Sánchez', 'departamento': 'RRHH', 'salario': 54653, 'fecha_contratacion': '2020-10-20', 'email': 'laura.sánchez9@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b30'), 'id': 10, 'nombre': 'Luis', 'apellido': 'Gómez', 'departamento': 'Producción', 'salario': 60947, 'fecha_contratacion': '2016-10-03', 'email': 'luis.gómez10@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b31'), 'id': 11, 'nombre': 'Ana', 'apellido': 'Gómez', 'departamento': 'Logística', 'salario': 40526, 'fecha_contratacion': '2018-01-25', 'email': 'ana.gómez11@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b32'), 'id': 12, 'nombre': 'Luis', 'apellido': 'Pérez', 'departamento': 'IT', 'salario': 42006, 'fecha_contratacion': '2021-09-27', 'email': 'luis.pérez12@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b35'), 'id': 15, 'nombre': 'Jorge', 'apellido': 'Díaz', 'departamento': 'Marketing', 'salario': 64705, 'fecha_contratacion': '2021-10-30', 'email': 'jorge.díaz15@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b36'), 'id': 16, 'nombre': 'Juan', 'apellido': 'García', 'departamento': 'IT', 'salario': 36350, 'fecha_contratacion': '2023-03-10', 'email': 'juan.garcía16@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b38'), 'id': 18, 'nombre': 'Laura', 'apellido': 'Martínez', 'departamento': 'Finanzas', 'salario': 34694, 'fecha_contratacion': '2022-08-08', 'email': 'laura.martínez18@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b39'), 'id': 19, 'nombre': 'María', 'apellido': 'Gómez', 'departamento': 'RRHH', 'salario': 32968, 'fecha_contratacion': '2024-03-30', 'email': 'maría.gómez19@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b3a'), 'id': 20, 'nombre': 'María', 'apellido': 'Gómez', 'departamento': 'Marketing', 'salario': 52123, 'fecha_contratacion': '2019-06-01', 'email': 'maría.gómez20@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b3b'), 'id': 21, 'nombre': 'Carlos', 'apellido': 'Morales', 'departamento': 'Finanzas', 'salario': 52560, 'fecha_contratacion': '2019-07-22', 'email': 'carlos.morales21@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b3c'), 'id': 22, 'nombre': 'Elena', 'apellido': 'Ruiz', 'departamento': 'Finanzas', 'salario': 47998, 'fecha_contratacion': '2017-12-30', 'email': 'elena.ruiz22@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b3d'), 'id': 23, 'nombre': 'Laura', 'apellido': 'Fernández', 'departamento': 'Ventas', 'salario': 44486, 'fecha_contratacion': '2021-06-16', 'email': 'laura.fernández23@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b3e'), 'id': 24, 'nombre': 'Pablo', 'apellido': 'López', 'departamento': 'Producción', 'salario': 33632, 'fecha_contratacion': '2021-01-09', 'email': 'pablo.lópez24@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b3f'), 'id': 25, 'nombre': 'Sara', 'apellido': 'Martínez', 'departamento': 'IT', 'salario': 59356, 'fecha_contratacion': '2017-05-17', 'email': 'sara.martínez25@empresa.com', 'activo': False}

# %%
print("\n4. Empleados con edad entre 30 y 40 años (Sintaxis correcta para campo 'edad'):")
# Recordatorio: Este query solo funcionará si los documentos tienen un campo 'edad'
query_edad_rango = {"edad": {"$gte": 30, "$lte": 40}}
for empleado in coleccion.find(query_edad_rango).limit(20):
    print(empleado)
# Out:
# 4. Empleados con edad entre 30 y 40 años (Sintaxis correcta para campo 'edad'):

# %%
print("\n5. Empleados inactivos (activo = False):")
query_inactivos = {"activo": False}
for empleado in coleccion.find(query_inactivos).limit(20):
    print(empleado)
# Out:
# 5. Empleados inactivos (activo = False):
# {'_id': ObjectId('6964e26d7370496126b61b28'), 'id': 2, 'nombre': 'María', 'apellido': 'Fernández', 'departamento': 'Logística', 'salario': 49873, 'fecha_contratacion': '2021-06-04', 'email': 'maría.fernández2@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b2a'), 'id': 4, 'nombre': 'Luis', 'apellido': 'Pérez', 'departamento': 'IT', 'salario': 64492, 'fecha_contratacion': '2018-06-17', 'email': 'luis.pérez4@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b2c'), 'id': 6, 'nombre': 'Juan', 'apellido': 'Martínez', 'departamento': 'Producción', 'salario': 43478, 'fecha_contratacion': '2020-08-29', 'email': 'juan.martínez6@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b2e'), 'id': 8, 'nombre': 'Ana', 'apellido': 'Morales', 'departamento': 'Marketing', 'salario': 25181, 'fecha_contratacion': '2023-12-07', 'email': 'ana.morales8@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b31'), 'id': 11, 'nombre': 'Ana', 'apellido': 'Gómez', 'departamento': 'Logística', 'salario': 40526, 'fecha_contratacion': '2018-01-25', 'email': 'ana.gómez11@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b35'), 'id': 15, 'nombre': 'Jorge', 'apellido': 'Díaz', 'departamento': 'Marketing', 'salario': 64705, 'fecha_contratacion': '2021-10-30', 'email': 'jorge.díaz15@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b36'), 'id': 16, 'nombre': 'Juan', 'apellido': 'García', 'departamento': 'IT', 'salario': 36350, 'fecha_contratacion': '2023-03-10', 'email': 'juan.garcía16@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b38'), 'id': 18, 'nombre': 'Laura', 'apellido': 'Martínez', 'departamento': 'Finanzas', 'salario': 34694, 'fecha_contratacion': '2022-08-08', 'email': 'laura.martínez18@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b3b'), 'id': 21, 'nombre': 'Carlos', 'apellido': 'Morales', 'departamento': 'Finanzas', 'salario': 52560, 'fecha_contratacion': '2019-07-22', 'email': 'carlos.morales21@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b3c'), 'id': 22, 'nombre': 'Elena', 'apellido': 'Ruiz', 'departamento': 'Finanzas', 'salario': 47998, 'fecha_contratacion': '2017-12-30', 'email': 'elena.ruiz22@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b3f'), 'id': 25, 'nombre': 'Sara', 'apellido': 'Martínez', 'departamento': 'IT', 'salario': 59356, 'fecha_contratacion': '2017-05-17', 'email': 'sara.martínez25@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b41'), 'id': 27, 'nombre': 'Juan', 'apellido': 'García', 'departamento': 'Ventas', 'salario': 39180, 'fecha_contratacion': '2021-06-08', 'email': 'juan.garcía27@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b44'), 'id': 30, 'nombre': 'María', 'apellido': 'Pérez', 'departamento': 'Logística', 'salario': 27637, 'fecha_contratacion': '2018-03-30', 'email': 'maría.pérez30@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b45'), 'id': 31, 'nombre': 'Jorge', 'apellido': 'Morales', 'departamento': 'Finanzas', 'salario': 41238, 'fecha_contratacion': '2024-01-10', 'email': 'jorge.morales31@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b48'), 'id': 34, 'nombre': 'Ana', 'apellido': 'López', 'departamento': 'RRHH', 'salario': 51306, 'fecha_contratacion': '2018-06-01', 'email': 'ana.lópez34@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b4a'), 'id': 36, 'nombre': 'María', 'apellido': 'Ruiz', 'departamento': 'Logística', 'salario': 55856, 'fecha_contratacion': '2019-03-07', 'email': 'maría.ruiz36@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b4d'), 'id': 39, 'nombre': 'Ana', 'apellido': 'Pérez', 'departamento': 'RRHH', 'salario': 38590, 'fecha_contratacion': '2019-11-12', 'email': 'ana.pérez39@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b4e'), 'id': 40, 'nombre': 'Luis', 'apellido': 'López', 'departamento': 'Ventas', 'salario': 42622, 'fecha_contratacion': '2022-02-09', 'email': 'luis.lópez40@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b50'), 'id': 42, 'nombre': 'Luis', 'apellido': 'Gómez', 'departamento': 'Ventas', 'salario': 52721, 'fecha_contratacion': '2025-06-03', 'email': 'luis.gómez42@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b54'), 'id': 46, 'nombre': 'Luis', 'apellido': 'García', 'departamento': 'Finanzas', 'salario': 54555, 'fecha_contratacion': '2020-01-23', 'email': 'luis.garcía46@empresa.com', 'activo': False}

# %%
print("\n6. Empleados cuyo nombre empieza por 'A' (Insensible a mayúsculas/minúsculas):")
query_nombre_empieza_a = {"nombre": {"$regex": "^A", "$options": "i"}}
for empleado in coleccion.find(query_nombre_empieza_a).limit(20):
    print(empleado)
# Out:
# 6. Empleados cuyo nombre empieza por 'A' (Insensible a mayúsculas/minúsculas):
# {'_id': ObjectId('6964e26d7370496126b61b2b'), 'id': 5, 'nombre': 'Ana', 'apellido': 'Fernández', 'departamento': 'RRHH', 'salario': 47430, 'fecha_contratacion': '2023-08-02', 'email': 'ana.fernández5@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b2e'), 'id': 8, 'nombre': 'Ana', 'apellido': 'Morales', 'departamento': 'Marketing', 'salario': 25181, 'fecha_contratacion': '2023-12-07', 'email': 'ana.morales8@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b31'), 'id': 11, 'nombre': 'Ana', 'apellido': 'Gómez', 'departamento': 'Logística', 'salario': 40526, 'fecha_contratacion': '2018-01-25', 'email': 'ana.gómez11@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b42'), 'id': 28, 'nombre': 'Ana', 'apellido': 'Ruiz', 'departamento': 'Finanzas', 'salario': 25936, 'fecha_contratacion': '2019-06-20', 'email': 'ana.ruiz28@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b48'), 'id': 34, 'nombre': 'Ana', 'apellido': 'López', 'departamento': 'RRHH', 'salario': 51306, 'fecha_contratacion': '2018-06-01', 'email': 'ana.lópez34@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b4b'), 'id': 37, 'nombre': 'Ana', 'apellido': 'García', 'departamento': 'Finanzas', 'salario': 33600, 'fecha_contratacion': '2016-05-18', 'email': 'ana.garcía37@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b4d'), 'id': 39, 'nombre': 'Ana', 'apellido': 'Pérez', 'departamento': 'RRHH', 'salario': 38590, 'fecha_contratacion': '2019-11-12', 'email': 'ana.pérez39@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b59'), 'id': 51, 'nombre': 'Ana', 'apellido': 'Gómez', 'departamento': 'RRHH', 'salario': 36284, 'fecha_contratacion': '2022-01-05', 'email': 'ana.gómez51@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b87'), 'id': 97, 'nombre': 'Ana', 'apellido': 'Sánchez', 'departamento': 'RRHH', 'salario': 46320, 'fecha_contratacion': '2016-06-13', 'email': 'ana.sánchez97@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61b8d'), 'id': 103, 'nombre': 'Ana', 'apellido': 'Fernández', 'departamento': 'Marketing', 'salario': 53805, 'fecha_contratacion': '2019-12-21', 'email': 'ana.fernández103@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61b9b'), 'id': 117, 'nombre': 'Ana', 'apellido': 'Ruiz', 'departamento': 'Logística', 'salario': 62197, 'fecha_contratacion': '2020-03-26', 'email': 'ana.ruiz117@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61ba0'), 'id': 122, 'nombre': 'Ana', 'apellido': 'Ruiz', 'departamento': 'RRHH', 'salario': 61205, 'fecha_contratacion': '2016-10-04', 'email': 'ana.ruiz122@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61bbd'), 'id': 151, 'nombre': 'Ana', 'apellido': 'Martínez', 'departamento': 'Logística', 'salario': 26109, 'fecha_contratacion': '2018-02-11', 'email': 'ana.martínez151@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61bc0'), 'id': 154, 'nombre': 'Ana', 'apellido': 'Pérez', 'departamento': 'Finanzas', 'salario': 38009, 'fecha_contratacion': '2019-01-29', 'email': 'ana.pérez154@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61bc2'), 'id': 156, 'nombre': 'Ana', 'apellido': 'Pérez', 'departamento': 'Ventas', 'salario': 34045, 'fecha_contratacion': '2018-03-17', 'email': 'ana.pérez156@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61bd2'), 'id': 172, 'nombre': 'Ana', 'apellido': 'Morales', 'departamento': 'Ventas', 'salario': 62820, 'fecha_contratacion': '2023-05-01', 'email': 'ana.morales172@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61bd5'), 'id': 175, 'nombre': 'Ana', 'apellido': 'Sánchez', 'departamento': 'Producción', 'salario': 63040, 'fecha_contratacion': '2021-09-04', 'email': 'ana.sánchez175@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61bdc'), 'id': 182, 'nombre': 'Ana', 'apellido': 'López', 'departamento': 'Producción', 'salario': 41861, 'fecha_contratacion': '2017-10-06', 'email': 'ana.lópez182@empresa.com', 'activo': False}
# {'_id': ObjectId('6964e26d7370496126b61be2'), 'id': 188, 'nombre': 'Ana', 'apellido': 'Martínez', 'departamento': 'Producción', 'salario': 51471, 'fecha_contratacion': '2025-07-21', 'email': 'ana.martínez188@empresa.com', 'activo': True}
# {'_id': ObjectId('6964e26d7370496126b61beb'), 'id': 197, 'nombre': 'Ana', 'apellido': 'Morales', 'departamento': 'Finanzas', 'salario': 33099, 'fecha_contratacion': '2017-07-26', 'email': 'ana.morales197@empresa.com', 'activo': True}

# %% [markdown]
# **B. Consultas Avanzadas**
#
# 1. Obtén los empleados cuyo salario no esté entre 20000 y 40000.
# 2. Busca los empleados cuyo departamento esté en una lista (por ejemplo: Ventas, IT, RRHH).
# 3. Encuentra empleados con salario superior a la media (primero obtén la media con aggregate).
# 4. Muestra empleados cuyo nombre contenga "ez" (búsqueda regex).

# %%
#las llaves son el and 
for doc in db.empleados.find({"salario":{"$gte":40000}, {"$lte":20000}}),
{"nombre":1, "salario"}
print("1. Empleados con salario NO entre 20000 y 40000:")
query_salario_fuera_rango = {
    "$or": [
        {"salario": {"$lt": 20000}},
        {"salario": {"$gt": 40000}}
    ]
}

for empleado in coleccion.find(query_salario_fuera_rango).limit(20):
    print(f"{empleado['nombre']} {empleado['apellido']} - Salario: {empleado['salario']}")
# Out:
# 1. Empleados con salario NO entre 20000 y 40000:
# María Fernández - Salario: 49873
# Elena Fernández - Salario: 62033
# Luis Pérez - Salario: 64492
# Ana Fernández - Salario: 47430
# Juan Martínez - Salario: 43478
# Laura Sánchez - Salario: 54653
# Luis Gómez - Salario: 60947
# Ana Gómez - Salario: 40526
# Luis Pérez - Salario: 42006
# Jorge Díaz - Salario: 64705
# María Gómez - Salario: 52123
# Carlos Morales - Salario: 52560
# Elena Ruiz - Salario: 47998
# Laura Fernández - Salario: 44486
# Sara Martínez - Salario: 59356
# Jorge García - Salario: 42154
# Jorge Morales - Salario: 41238
# Laura López - Salario: 42057
# Ana López - Salario: 51306
# Juan Díaz - Salario: 47320

# %%
print("\n2. Empleados en Ventas, IT o RRHH:")
lista_departamentos = ["Ventas", "IT", "RRHH"]
query_departamento_in = {"departamento": {"$in": lista_departamentos}}

for empleado in coleccion.find(query_departamento_in).limit(10):
    print(f"{empleado['nombre']} - Departamento: {empleado['departamento']}")
# Out:
# 2. Empleados en Ventas, IT o RRHH:
# Elena - Departamento: RRHH
# Elena - Departamento: RRHH
# Luis - Departamento: IT
# Ana - Departamento: RRHH
# Laura - Departamento: RRHH
# Laura - Departamento: RRHH
# Luis - Departamento: IT
# Juan - Departamento: IT
# María - Departamento: Ventas
# María - Departamento: RRHH

# %%
print("\n3. Empleados con salario superior a la media:")

# --- Paso 1: Calcular el salario medio usando Aggregation Pipeline ---
pipeline_media = [
    {"$group": {"_id": None, "salario_medio": {"$avg": "$salario"}}}
]
resultado_media = list(coleccion.aggregate(pipeline_media))

if resultado_media:
    salario_medio = resultado_media[0]["salario_medio"]
    print(f"-> Salario Medio de la empresa: {salario_medio:.2f}")

    # --- Paso 2: Consultar empleados con salario > media ---
    query_salario_superior_media = {"salario": {"$gt": salario_medio}}
    
    for empleado in coleccion.find(query_salario_superior_media).sort("salario", -1).limit(10): # Ordenado por salario descendente
        print(f"{empleado['nombre']} {empleado['apellido']} - Salario: {empleado['salario']}")
else:
    print("No se encontraron datos para calcular la media.")
# Out:
# 3. Empleados con salario superior a la media:
# -> Salario Medio de la empresa: 41298.30
# María Morales - Salario: 64992
# María Morales - Salario: 64992
# María Morales - Salario: 64992
# Laura Gómez - Salario: 64948
# Laura Gómez - Salario: 64948
# Laura Gómez - Salario: 64948
# Jorge Martínez - Salario: 64912
# Jorge Martínez - Salario: 64912
# Jorge Martínez - Salario: 64912
# Laura Ruiz - Salario: 64891

# %%
print("\n4. Empleados cuyo nombre contenga 'ez':")
# Expresión regular: /ez/i
query_nombre_contiene_ez = {"nombre": {"$regex": "ez", "$options": "i"}}

for empleado in coleccion.find(query_nombre_contiene_ez):
    print(f"{empleado['nombre']} {empleado['apellido']} - Email: {empleado['email']}")
# Out:
# 4. Empleados cuyo nombre contenga 'ez':

# %% [markdown]
# **C. Ordenación y Límites**
#
# 1. Lista los 10 empleados con mayor salario.
# 2. Devuelve los empleados ordenados por edad descendente.

# %%
print("1. Los 10 empleados con mayor salario:")

# Pipeline: Ordenar por salario descendente (-1) y limitar a 10
results = coleccion.find({}) \
    .sort("salario", -1) \
    .limit(10)

# Mostrar resultados con los campos relevantes
for empleado in results:
    print(f"Salario: {empleado['salario']}, Nombre: {empleado['nombre']} {empleado['apellido']}, Depto: {empleado['departamento']}")
# Out:
# 1. Los 10 empleados con mayor salario:
# Salario: 64992, Nombre: María Morales, Depto: Logística
# Salario: 64992, Nombre: María Morales, Depto: Logística
# Salario: 64992, Nombre: María Morales, Depto: Logística
# Salario: 64948, Nombre: Laura Gómez, Depto: Ventas
# Salario: 64948, Nombre: Laura Gómez, Depto: Ventas
# Salario: 64948, Nombre: Laura Gómez, Depto: Ventas
# Salario: 64912, Nombre: Jorge Martínez, Depto: Finanzas
# Salario: 64912, Nombre: Jorge Martínez, Depto: Finanzas
# Salario: 64912, Nombre: Jorge Martínez, Depto: Finanzas
# Salario: 64891, Nombre: Laura Ruiz, Depto: Ventas

# %%
print("\n2. Empleados ordenados por edad descendente (Sintaxis correcta para campo 'edad'):")

# Pipeline: Ordenar por edad descendente (-1)
# Advertencia: Esta consulta puede no devolver resultados ya que 'edad' no existe en empresa.csv
results = coleccion.find({}).limit(10) \
    .sort("edad", -1)

# Mostrar resultados
for empleado in results:
    # Se añade una verificación simple para evitar errores si el campo 'edad' no existe
    edad_display = empleado.get('edad', 'N/D')
    print(f"Edad: {edad_display}, Nombre: {empleado['nombre']} {empleado['apellido']}")
# Out:
# 2. Empleados ordenados por edad descendente (Sintaxis correcta para campo 'edad'):
# Edad: N/D, Nombre: Laura Sánchez
# Edad: N/D, Nombre: Luis Gómez
# Edad: N/D, Nombre: Ana Fernández
# Edad: N/D, Nombre: Ana Morales
# Edad: N/D, Nombre: Juan Martínez
# Edad: N/D, Nombre: Luis Pérez
# Edad: N/D, Nombre: María Fernández
# Edad: N/D, Nombre: Elena Martínez
# Edad: N/D, Nombre: Elena Fernández
# Edad: N/D, Nombre: Laura Pérez

# %% [markdown]
# **D. Agregaciones**
# 1. Calcula el salario medio por departamento.
# 2. Cuenta cuántos empleados hay por cada departamento.
# 3. Devuelve el empleado mejor pagado de cada departamento.
# 4. Suma el salario total de toda la empresa.
# 5. Consulta qué departamento tiene más empleados activos.
# 6. Obtén una lista con los distintos departamentos existentes ($group).

# %%
print("1. Salario Medio por Departamento:")

pipeline_salario_medio = [
    {
        "$group": {
            "_id": "$departamento",
            "salario_medio": {"$avg": "$salario"}
        }
    },
    # Opcional: ordenar por salario medio descendente
    {"$sort": {"salario_medio": -1}}
]

for resultado in coleccion.aggregate(pipeline_salario_medio):
    print(f"Departamento: {resultado['_id']}, Salario Medio: {resultado['salario_medio']:.2f}")
# Out:
# 1. Salario Medio por Departamento:
# Departamento: Finanzas, Salario Medio: 42592.61
# Departamento: Producción, Salario Medio: 42061.83
# Departamento: IT, Salario Medio: 41358.66
# Departamento: Ventas, Salario Medio: 41116.85
# Departamento: Marketing, Salario Medio: 40959.95
# Departamento: Logística, Salario Medio: 40690.79
# Departamento: RRHH, Salario Medio: 40470.60

# %%
print("\n2. Conteo de Empleados por Departamento:")

pipeline_conteo = [
    {
        "$group": {
            "_id": "$departamento",
            "total_empleados": {"$sum": 1}
        }
    },
    # Opcional: ordenar por el total de empleados descendente
    {"$sort": {"total_empleados": -1}}
]

for resultado in coleccion.aggregate(pipeline_conteo):
    print(f"Departamento: {resultado['_id']}, Total Empleados: {resultado['total_empleados']}")
# Out:
# 2. Conteo de Empleados por Departamento:
# Departamento: Marketing, Total Empleados: 474
# Departamento: RRHH, Total Empleados: 471
# Departamento: Producción, Total Empleados: 444
# Departamento: Logística, Total Empleados: 444
# Departamento: Finanzas, Total Empleados: 405
# Departamento: IT, Total Empleados: 393
# Departamento: Ventas, Total Empleados: 369

# %%
print("\n3. Empleado Mejor Pagado de cada Departamento:")

pipeline_mejor_pagado = [
    # 1. Ordenar por departamento (para agrupar) y luego por salario descendente
    {"$sort": {"departamento": 1, "salario": -1}},
    
    # 2. Agrupar por departamento y tomar el primer documento (que es el de mayor salario)
    {
        "$group": {
            "_id": "$departamento",
            "max_salario": {"$first": "$salario"},
            "nombre": {"$first": "$nombre"},
            "apellido": {"$first": "$apellido"},
        }
    },
    # 3. Opcional: ordenar por el salario máximo
    {"$sort": {"max_salario": -1}}
]

for resultado in coleccion.aggregate(pipeline_mejor_pagado):
    print(f"Depto: {resultado['_id']}, Nombre: {resultado['nombre']} {resultado['apellido']}, Salario: {resultado['max_salario']}")
# Out:
# 3. Empleado Mejor Pagado de cada Departamento:
# Depto: Logística, Nombre: María Morales, Salario: 64992
# Depto: Ventas, Nombre: Laura Gómez, Salario: 64948
# Depto: Finanzas, Nombre: Jorge Martínez, Salario: 64912
# Depto: IT, Nombre: Jorge Ruiz, Salario: 64869
# Depto: Marketing, Nombre: Sara Díaz, Salario: 64832
# Depto: Producción, Nombre: Juan García, Salario: 64546
# Depto: RRHH, Nombre: Ana Ruiz, Salario: 64339

# %%
print("\n4. Suma del Salario Total de toda la Empresa:")

pipeline_salario_total = [
    {
        "$group": {
            "_id": None,
            "salario_total": {"$sum": "$salario"}
        }
    }
]

resultado = list(coleccion.aggregate(pipeline_salario_total))

if resultado:
    print(f"Salario Total: {resultado[0]['salario_total']:.2f}")
# Out:
# 4. Suma del Salario Total de toda la Empresa:
# Salario Total: 123894912.00

# %%
print("\n5. Departamento con más Empleados Activos:")

pipeline_activos = [
    # 1. Filtrar solo los empleados activos
    {"$match": {"activo": True}},
    
    # 2. Contar los empleados activos por departamento
    {"$group": {"_id": "$departamento", "empleados_activos": {"$sum": 1}}},
    
    # 3. Ordenar para poner el máximo primero
    {"$sort": {"empleados_activos": -1}},
    
    # 4. Limitar al primer resultado (el que tiene el mayor conteo)
    {"$limit": 1}
]

resultado = list(coleccion.aggregate(pipeline_activos))

if resultado:
    print(f"El departamento con más activos es: {resultado[0]['_id']} con {resultado[0]['empleados_activos']} empleados.")
# Out:
# 5. Departamento con más Empleados Activos:
# El departamento con más activos es: RRHH con 264 empleados.

# %%
print("\n6. Lista de Departamentos Únicos:")

pipeline_departamentos = [
    {
        "$group": {
            "_id": "$departamento"
        }
    }
]

departamentos = [doc['_id'] for doc in coleccion.aggregate(pipeline_departamentos)]

print(departamentos)
# Out:
# 6. Lista de Departamentos Únicos:
# ['Finanzas', 'IT', 'RRHH', 'Logística', 'Ventas', 'Marketing', 'Producción']

# %% [markdown]
# **E. Actualizaciones**
#
# 1. Incrementa el salario un 5% a todos los empleados del departamento IT.
# 2. Marca como inactivos todos los empleados cuyo salario sea inferior a 18000.

# %%
print("1. Incrementando salario un 5% a empleados de IT...")

# 1. Definir la consulta (query) para encontrar a los empleados de IT
query_it = {"departamento": "IT"}

# 2. Definir la actualización (update) usando el operador $mul
# $mul: Multiplica el valor actual de 'salario' por 1.05
update_incremento = {"$mul": {"salario": 1.05}}

# 3. Ejecutar la actualización masiva
resultado = coleccion.update_many(query_it, update_incremento)

print(f"Documentos coincidentes: {resultado.matched_count}")
print(f"Documentos modificados: {resultado.modified_count}")

# Opcional: Verificar un empleado de IT
print("\nVerificación (Ejemplo de empleado de IT):")
for empleado in coleccion.find(query_it).limit(2):
    print(f"Nombre: {empleado['nombre']} {empleado['apellido']}, Nuevo Salario: {empleado['salario']:.2f}")
# Out:
# 1. Incrementando salario un 5% a empleados de IT...
# Documentos coincidentes: 393
# Documentos modificados: 393
#
# Verificación (Ejemplo de empleado de IT):
# Nombre: Luis Pérez, Nuevo Salario: 67716.60
# Nombre: Luis Pérez, Nuevo Salario: 44106.30

# %%
print("\n2. Marcando como inactivos a empleados con salario < 18000...")

# 1. Definir la consulta (query) para encontrar salarios menores a 18000
query_salario_bajo = {"salario": {"$lt": 18000}}

# 2. Definir la actualización (update) usando el operador $set
# $set: Establece el valor del campo 'activo' a False
update_inactivo = {"$set": {"activo": False}}

# 3. Ejecutar la actualización masiva
resultado = coleccion.update_many(query_salario_bajo, update_inactivo)

print(f"Documentos coincidentes: {resultado.matched_count}")
print(f"Documentos modificados: {resultado.modified_count}")

# Opcional: Verificar los empleados inactivos recién marcados
print("\nVerificación (Ejemplos de inactivos con salario bajo):")
for empleado in coleccion.find({"salario": {"$lt": 18000}}).limit(3):
    print(f"Nombre: {empleado['nombre']} {empleado['apellido']}, Salario: {empleado['salario']:.2f}, Activo: {empleado['activo']}")
# Out:
# 2. Marcando como inactivos a empleados con salario < 18000...
# Documentos coincidentes: 0
# Documentos modificados: 0
#
# Verificación (Ejemplos de inactivos con salario bajo):

# %% [markdown]
# **F. Eliminaciones**
#
# 1. Elimina un empleado por email concreto.
# 2. Borra todos los empleados inactivos.
# 3. Elimina empleados con salario inferior a 30000.
# 4. Elimina empleados de un departamento específico.
# 5. Vacía la colección empleados.

# %%
print("1. Eliminando empleado por email concreto (elena.martínez1@empresa.com)...")

# Email de ejemplo a eliminar
email_a_eliminar = "elena.martínez1@empresa.com"

query_email = {"email": email_a_eliminar}

# Ejecutar la eliminación de un solo documento
resultado = coleccion.delete_one(query_email)

print(f"Documentos eliminados: {resultado.deleted_count}")

# Verificar si el documento aún existe
print(f"Verificación: ¿Existe {email_a_eliminar}? -> {coleccion.find_one(query_email) is not None}")
# Out:
# 1. Eliminando empleado por email concreto (elena.martínez1@empresa.com)...
# Documentos eliminados: 1
# Verificación: ¿Existe elena.martínez1@empresa.com? -> True

# %%
# [Recordatorio: Si ejecutaste el punto 1, considera recargar los datos antes de ejecutar este punto]
print("\n2. Borrando todos los empleados inactivos (activo = False)...")

query_inactivos = {"activo": False}

# Ejecutar la eliminación masiva
resultado = coleccion.delete_many(query_inactivos)

print(f"Documentos inactivos eliminados: {resultado.deleted_count}")

# Verificar cuántos quedan inactivos
print(f"Verificación: Total de documentos inactivos restantes: {coleccion.count_documents(query_inactivos)}")
# Out:
# 2. Borrando todos los empleados inactivos (activo = False)...
# Documentos inactivos eliminados: 1476
# Verificación: Total de documentos inactivos restantes: 0

# %%
# [Recordatorio: Si ejecutaste los puntos anteriores, considera recargar los datos]
print("\n3. Eliminando empleados con salario inferior a 30000...")

query_salario_bajo = {"salario": {"$lt": 30000}}

# Ejecutar la eliminación masiva
resultado = coleccion.delete_many(query_salario_bajo)

print(f"Documentos eliminados por salario bajo: {resultado.deleted_count}")

# Verificar cuántos quedan con salario bajo
print(f"Verificación: Total de documentos con salario < 30000 restantes: {coleccion.count_documents(query_salario_bajo)}")
# Out:
# 3. Eliminando empleados con salario inferior a 30000...
# Documentos eliminados por salario bajo: 422
# Verificación: Total de documentos con salario < 30000 restantes: 0

# %%
# [Recordatorio: Si ejecutaste los puntos anteriores, considera recargar los datos]
print("\n4. Eliminando empleados del departamento 'Logística'...")

departamento_a_eliminar = "Logística"
query_departamento = {"departamento": departamento_a_eliminar}

# Ejecutar la eliminación masiva
resultado = coleccion.delete_many(query_departamento)

print(f"Documentos del departamento '{departamento_a_eliminar}' eliminados: {resultado.deleted_count}")

# Verificar cuántos quedan en ese departamento
print(f"Verificación: Total de documentos en '{departamento_a_eliminar}' restantes: {coleccion.count_documents(query_departamento)}")
# Out:
# 4. Eliminando empleados del departamento 'Logística'...
# Documentos del departamento 'Logística' eliminados: 165
# Verificación: Total de documentos en 'Logística' restantes: 0

# %%
# [Recordatorio: Esta acción elimina TODOS los documentos]
print("\n5. Vaciando la colección de empleados...")

# El query vacío {} coincide con todos los documentos
query_todo = {}

# Ejecutar la eliminación masiva de toda la colección
resultado = coleccion.delete_many(query_todo)

print(f"Documentos eliminados (Colección vaciada): {resultado.deleted_count}")

# Verificar el conteo total
print(f"Verificación: Total de documentos en la colección: {coleccion.count_documents({})}")
# Out:
# 5. Vaciando la colección de empleados...
# Documentos eliminados (Colección vaciada): 936
# Verificación: Total de documentos en la colección: 0

# %% [markdown]
# G. **Indices**
#
# 1. Vuelve a cargar el fichero empresa.csv
# 2. Crea un índice sobre el campo nombre y comprueba cómo cambia el tiempo de consulta.
# 3. Crea un índice compuesto por departamento + salario e identifica para qué tipo de consultas es útil.
# 4. Comprueba en Compass qué índices existen actualmente en la colección.
# 5. Realiza una consulta que se beneficie de un índice y observa el plan de ejecución (explain()).
# 6. Elimina un índice y comprueba cómo afecta al rendimiento.

# %%
import csv
from pymongo.errors import ConnectionFailure

print("1. Recargando el fichero empresa.csv en la colección 'empleados'...")

try:
    # Asegurarse de que la conexión esté activa (usando la IP de Docker corregida)
    # Si la conexión está en una celda anterior, no es necesario redefinir client aquí
    # client = MongoClient('mongodb://172.18.0.3:27017/') 
    
    db = client["database"]
    coleccion = db["empleados"]
    
    empleados = []
    with open("empresa.csv", "r", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in reader:
            # Conversión de tipos
            row["id"] = int(row["id"])
            row["salario"] = int(row["salario"])
            row["activo"] = True if row["activo"] == "True" else False
            empleados.append(row)
    
    # Limpiar y reinsertar
    coleccion.delete_many({})
    coleccion.insert_many(empleados)
    print(f"-> Datos recargados. Total de documentos: {coleccion.count_documents({})}")

except ConnectionFailure:
    print("Error: Conexión a MongoDB fallida. Asegúrate de que el contenedor esté corriendo.")
except FileNotFoundError:
    print("Error: No se encontró el archivo 'empresa.csv'.")
# Out:
# 1. Recargando el fichero empresa.csv en la colección 'empleados'...
# -> Datos recargados. Total de documentos: 1000

# %%
import time

campo_indice_simple = "nombre"

# --- Paso 2A: Medir tiempo sin índice ---
print("\n2A. Consulta sin índice en el campo 'nombre'...")
tiempo_inicio_sin = time.time()
coleccion.find({campo_indice_simple: "Ana"}).explain() # Usamos explain() para no cargar todos los datos, pero simular la búsqueda
tiempo_fin_sin = time.time()
print(f"Tiempo sin índice: {(tiempo_fin_sin - tiempo_inicio_sin) * 1000:.2f} ms")

# --- Paso 2B: Crear índice ---
coleccion.create_index([(campo_indice_simple, 1)])
print(f"-> Índice simple en '{campo_indice_simple}' creado.")

# --- Paso 2C: Medir tiempo con índice ---
print("2C. Consulta con índice en el campo 'nombre'...")
tiempo_inicio_con = time.time()
coleccion.find({campo_indice_simple: "Ana"}).explain()
tiempo_fin_con = time.time()
print(f"Tiempo CON índice: {(tiempo_fin_con - tiempo_inicio_con) * 1000:.2f} ms")
# Out:
# 2A. Consulta sin índice en el campo 'nombre'...
# Tiempo sin índice: 1.47 ms
# -> Índice simple en 'nombre' creado.
# 2C. Consulta con índice en el campo 'nombre'...
# Tiempo CON índice: 1.37 ms

# %%
print("\n3. Creando índice compuesto en 'departamento' y 'salario'...")

coleccion.create_index([("departamento", 1), ("salario", -1)])
print("-> Índice compuesto en (departamento, salario) creado.")

print("\nUtilidad del Índice Compuesto (departamento, salario):")
print("* Consultas que filtran por DEPARTAMENTO (ej. `departamento='IT'`).")
print("* Consultas que filtran por DEPARTAMENTO y ordenan por SALARIO (ej. `departamento='IT'`.sort(`salario`, -1)).")
print("* Consultas que filtran solo por DEPARTAMENTO y/o SALARIO.")
# Out:
# 3. Creando índice compuesto en 'departamento' y 'salario'...
# -> Índice compuesto en (departamento, salario) creado.
#
# Utilidad del Índice Compuesto (departamento, salario):
# * Consultas que filtran por DEPARTAMENTO (ej. `departamento='IT'`).
# * Consultas que filtran por DEPARTAMENTO y ordenan por SALARIO (ej. `departamento='IT'`.sort(`salario`, -1)).
# * Consultas que filtran solo por DEPARTAMENTO y/o SALARIO.

# %%
print("\n4. Índices existentes en la colección 'empleados':")
indices = coleccion.list_indexes()
for indice in indices:
    print(indice)

print("\n-> Verificación manual en Compass: Conéctate a tu servidor MongoDB, selecciona la base de datos 'database', la colección 'empleados' y ve a la pestaña 'Indexes'.")
# Out:
# 4. Índices existentes en la colección 'empleados':
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
# SON([('v', 2), ('key', SON([('nombre', 1)])), ('name', 'nombre_1')])
# SON([('v', 2), ('key', SON([('departamento', 1), ('salario', -1)])), ('name', 'departamento_1_salario_-1')])
#
# -> Verificación manual en Compass: Conéctate a tu servidor MongoDB, selecciona la base de datos 'database', la colección 'empleados' y ve a la pestaña 'Indexes'.

# %%
print("\n5. Consulta que se beneficia del índice (departamento, salario) y plan de ejecución:")

# Consulta: Buscar empleados en 'IT' con salario > 60000
consulta_beneficiada = {"departamento": "IT", "salario": {"$gt": 60000}}

# Obtener el plan de ejecución
plan_ejecucion = coleccion.find(consulta_beneficiada).explain()

print(f"Resultados de la consulta: {coleccion.count_documents(consulta_beneficiada)}")
print("\n--- Plan de Ejecución (Winning Plan) ---")
print(f"Tipo de Scan: {plan_ejecucion['queryPlanner']['winningPlan']['stage']}")
print(f"Índice Utilizado: {plan_ejecucion['queryPlanner']['winningPlan'].get('inputStage', {}).get('indexName', 'N/A')}")

# Si el índice se utiliza, el 'stage' debe ser IXSCAN o similar.
# Out:
# 5. Consulta que se beneficia del índice (departamento, salario) y plan de ejecución:
# Resultados de la consulta: 19
#
# --- Plan de Ejecución (Winning Plan) ---
# Tipo de Scan: FETCH
# Índice Utilizado: departamento_1_salario_-1

# %%
print("\n6. Eliminando el índice 'nombre_1' y comprobando el rendimiento...")

# El nombre del índice por defecto es {campo}_{orden}, es decir, 'nombre_1'
nombre_indice_a_eliminar = "nombre_1"
coleccion.drop_index(nombre_indice_a_eliminar)
print(f"-> Índice '{nombre_indice_a_eliminar}' eliminado.")

# --- Medir tiempo después de eliminar el índice ---
tiempo_inicio_post_delete = time.time()
coleccion.find({campo_indice_simple: "Ana"}).explain()
tiempo_fin_post_delete = time.time()
print(f"Tiempo POST-ELIMINACIÓN: {(tiempo_fin_post_delete - tiempo_inicio_post_delete) * 1000:.2f} ms")

print("\nÍndices restantes:")
for indice in coleccion.list_indexes():
    print(indice)
# Out:
# 6. Eliminando el índice 'nombre_1' y comprobando el rendimiento...
# -> Índice 'nombre_1' eliminado.
# Tiempo POST-ELIMINACIÓN: 1.00 ms
#
# Índices restantes:
# SON([('v', 2), ('key', SON([('_id', 1)])), ('name', '_id_')])
# SON([('v', 2), ('key', SON([('departamento', 1), ('salario', -1)])), ('name', 'departamento_1_salario_-1')])
