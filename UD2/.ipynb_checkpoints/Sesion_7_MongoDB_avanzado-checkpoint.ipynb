# %% [markdown]
# # Sesion 7 MongoDb Avanzado
# Curso de Especialización en Inteligencia Artificial y Big Data
# Profesor: Juan Carlos Pérez González
# Departamento de Informática – IES de Teis

# %% [markdown]
# **Replicaset (replicación)**
#
# **Concepto**: conjunto de nodos que mantienen copias idénticas de los mismos datos.
#
# **Objetivo**: alta disponibilidad y tolerancia a fallos.
#
# 1. Un nodo es **primario**, permite **escritura**.
#
# 2. Los demás son **secundarios** y **replican datos del primario**.
#
# 3. Si el primario falla, **uno de los secundarios se convierte en primario** automáticamente.
#
# Esto permite protege tus datos de pérdida y permite lecturas distribuidas.
#
# IMPORTANTE: vamos a trabajar sin autenticación. No es lo que hay que hacer pero en Windows, los docker para trabajar con Replica-Set dan bastante problemas.
# En los apuntes esta la versión con autenticación con MV de Ubuntu que no da problemas.

# %% [markdown]
# ## Trabajando con Replica-sets

# %% [markdown]
# **Paso 1**. Creamos dentro de replicaset la carpeta data y dentrod de ella mongo1, mongo2 y mongo3, desde **powershell como administrador**
#
# Si miras el fichero docker mongo-replicaset lo entiendes.
#
# *New-Item -ItemType Directory -Force data\mongo1*
#
# *New-Item -ItemType Directory -Force data\mongo2*
#
# *New-Item -ItemType Directory -Force data\mongo3*

# %% [markdown]
# **Paso 2**. Ejecutamos el docker-compose replicaset que tenemos en 4.2.Almacen  **mongo-replica.set** fuera del directorio mongo-keyfaile pero dentro del directorio replicaset.
#
# *docker network create mongo-replicaset-net*
#
# *docker-compose -f mongo-replicaset.yml up -d*

# %% [markdown]
# **Paso 3.** Iniciamos la replica. Para ello nos conectamos al mongodb1
#
# Así sería con autenticación:
# *docker exec -it mongodb1 mongosh -u admin -p abc123 --authenticationDatabase admin*
#
# Pero como no tenemos autenticación **usamos este comando**:
#
# *docker exec -it mongodb1 mongo*
#
#
# y dentro de mongosh iniciamos la replicaset
#
#
# *rs.initiate({
#   _id: "rs0",
#   members: [
#     { _id: 0, host: "mongodb1:27017" },
#     { _id: 1, host: "mongodb2:27017" },
#     { _id: 2, host: "mongodb3:27017" }
#   ]
# })*
#
#
# *rs0* es el nombre del replicaset que le dimos en docker-compose
#
# Comprobamos que todo va bien:
#
# *rs.status()*

# %% [markdown]
# Vamos a conectarnos desde jupyterlab

# %%
from pymongo import MongoClient

cliente = MongoClient('mongodb1', 27017, replicaset='rs0')
db = cliente.test
print(db.list_collection_names())
# Out:
# []

# %%
#Comprobamos que ha descubierto automáticamente el resto de nodos
print(cliente.nodes)
# Out:
# frozenset({('mongodb3', 27017), ('mongodb2', 27017), ('mongodb1', 27017)})

# %%
import pandas as pd

# Cargar CSV
df = pd.read_csv("RegistroComprasOnline.csv")

# Ver las primeras filas
print(df.head())  # <- aquí agregamos print

# Conexión a la base y colección
db = cliente['bbdd']
coleccion = db['compras']

# Convertir a diccionarios e insertar
registros = df.to_dict(orient='records')
resultado = coleccion.insert_many(registros)

print(f"Se insertaron {len(resultado.inserted_ids)} registros.")
# Out:
#    IDCliente     Importecompra Fechacompra           Categoria  \
# 0       7302  412,734791193503    24/11/20                 CPU
# 1       1380  529,537228589387    04/08/22  RATONES Y TECLADOS
# 2       5747  707,833722678856    09/03/22             MONITOR
# 3       8383  196,881214919621    02/05/22                 CPU
# 4       3462  771,172392957508    27/01/21      ALMACENAMIENTO
#
#    Numerodeclicks Fechadenacimiento  Codigopostalenvio  \
# 0            12.0          24/03/04              15983
# 1            16.0          19/02/94              21668
# 2             5.0          22/09/85               2246
# 3             1.0          28/06/84              15568
# 4             9.0          17/04/72              15684
#
#    Tiemporealizacioncompra Clienteexistente
# 0                     60.0               SI
# 1                     80.0               SI
# 2                     25.0               SI
# 3                      5.0               SI
# 4                     45.0               NO
# Se insertaron 2271 registros.

# %%
#Hacemos una consulta
# Leer los primeros 10 documentos
primeros_10 = coleccion.find().limit(10)

# Imprimirlos
for doc in primeros_10:
    print(doc)
# Out:
# {'_id': ObjectId('6966a4a6d2df758917fe2e46'), 'IDCliente': 7302, 'Importecompra': '412,734791193503', 'Fechacompra': '24/11/20', 'Categoria': 'CPU', 'Numerodeclicks': 12.0, 'Fechadenacimiento': '24/03/04', 'Codigopostalenvio': 15983, 'Tiemporealizacioncompra': 60.0, 'Clienteexistente': 'SI'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e47'), 'IDCliente': 1380, 'Importecompra': '529,537228589387', 'Fechacompra': '04/08/22', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 16.0, 'Fechadenacimiento': '19/02/94', 'Codigopostalenvio': 21668, 'Tiemporealizacioncompra': 80.0, 'Clienteexistente': 'SI'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e48'), 'IDCliente': 5747, 'Importecompra': '707,833722678856', 'Fechacompra': '09/03/22', 'Categoria': 'MONITOR', 'Numerodeclicks': 5.0, 'Fechadenacimiento': '22/09/85', 'Codigopostalenvio': 2246, 'Tiemporealizacioncompra': 25.0, 'Clienteexistente': 'SI'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e49'), 'IDCliente': 8383, 'Importecompra': '196,881214919621', 'Fechacompra': '02/05/22', 'Categoria': 'CPU', 'Numerodeclicks': 1.0, 'Fechadenacimiento': '28/06/84', 'Codigopostalenvio': 15568, 'Tiemporealizacioncompra': 5.0, 'Clienteexistente': 'SI'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e4a'), 'IDCliente': 3462, 'Importecompra': '771,172392957508', 'Fechacompra': '27/01/21', 'Categoria': 'ALMACENAMIENTO', 'Numerodeclicks': 9.0, 'Fechadenacimiento': '17/04/72', 'Codigopostalenvio': 15684, 'Tiemporealizacioncompra': 45.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e4b'), 'IDCliente': 3922, 'Importecompra': '220,281940980377', 'Fechacompra': '24/06/22', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 9.0, 'Fechadenacimiento': '18/03/81', 'Codigopostalenvio': 7711, 'Tiemporealizacioncompra': 45.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e4c'), 'IDCliente': 3934, 'Importecompra': '625,570024974807', 'Fechacompra': '14/12/18', 'Categoria': 'MEMORIA', 'Numerodeclicks': 9.0, 'Fechadenacimiento': '09/05/79', 'Codigopostalenvio': 44121, 'Tiemporealizacioncompra': 45.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e4d'), 'IDCliente': 8021, 'Importecompra': '268,500143551309', 'Fechacompra': '20/02/15', 'Categoria': 'CPU', 'Numerodeclicks': 15.0, 'Fechadenacimiento': '20/09/01', 'Codigopostalenvio': 24549, 'Tiemporealizacioncompra': 75.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e4e'), 'IDCliente': 6671, 'Importecompra': '44,8126451748506', 'Fechacompra': '20/07/19', 'Categoria': 'ALMACENAMIENTO', 'Numerodeclicks': 7.0, 'Fechadenacimiento': '07/11/83', 'Codigopostalenvio': 29738, 'Tiemporealizacioncompra': 35.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e4f'), 'IDCliente': 7459, 'Importecompra': '784,614465022162', 'Fechacompra': '18/03/18', 'Categoria': 'MONITOR', 'Numerodeclicks': 2.0, 'Fechadenacimiento': '04/06/91', 'Codigopostalenvio': 45687, 'Tiemporealizacioncompra': 10.0, 'Clienteexistente': 'NO'}

# %%
#Una vez parado el primario, comprobamos los nodos reconocidos
#Comprobamos que ha descubierto automáticamente el resto de nodos
print(cliente.nodes)
# Out:
# frozenset({('mongodb3', 27017), ('mongodb2', 27017), ('mongodb1', 27017)})

# %%
#Repetimos la consulta para verificar que podemos seguir trabajando
print(coleccion.find_one())
# Out:
# {'_id': ObjectId('6966a4a6d2df758917fe2e46'), 'IDCliente': 7302, 'Importecompra': '412,734791193503', 'Fechacompra': '24/11/20', 'Categoria': 'CPU', 'Numerodeclicks': 12.0, 'Fechadenacimiento': '24/03/04', 'Codigopostalenvio': 15983, 'Tiemporealizacioncompra': 60.0, 'Clienteexistente': 'SI'}

# %%
#Y hacemos una inserción para comprobar que hay un nuevo primario
# (si no hubiese primario no podrías modificar)
resultado = coleccion.insert_one({'IDCliente': 34, 'test': 1})
print(resultado.inserted_id)
# Out:
# 6966a5fcd2df758917fe48e5

# %% [markdown]
# Nos conectamos a otro mongo y ves que se replicaron los datos

# %%
# Conectarse a mongodb2
cliente_mongo2 = MongoClient(
    'mongodb2',       # nombre del contenedor dentro de la red
    27017,            # puerto interno de Mongo
    replicaset='rs0', # replicaset que configuraste
    readPreference='secondaryPreferred'
)

# Seleccionamos la base y la colección
db_m2 = cliente_mongo2['bbdd']
coleccion_m2 = db_m2['compras']

# Leer 10 primeros documentos
for doc in coleccion_m2.find().limit(10):
    print(doc)
# Out:
# {'_id': ObjectId('6966a4a6d2df758917fe2e46'), 'IDCliente': 7302, 'Importecompra': '412,734791193503', 'Fechacompra': '24/11/20', 'Categoria': 'CPU', 'Numerodeclicks': 12.0, 'Fechadenacimiento': '24/03/04', 'Codigopostalenvio': 15983, 'Tiemporealizacioncompra': 60.0, 'Clienteexistente': 'SI'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e50'), 'IDCliente': 2652, 'Importecompra': '885,06668742108', 'Fechacompra': '20/06/18', 'Categoria': 'ALMACENAMIENTO', 'Numerodeclicks': 14.0, 'Fechadenacimiento': '14/12/02', 'Codigopostalenvio': 37110, 'Tiemporealizacioncompra': 70.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e8b'), 'IDCliente': 7953, 'Importecompra': '964,337884937664', 'Fechacompra': '22/12/19', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 1.0, 'Fechadenacimiento': '13/08/81', 'Codigopostalenvio': 18600, 'Tiemporealizacioncompra': 5.0, 'Clienteexistente': 'SI'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e4b'), 'IDCliente': 3922, 'Importecompra': '220,281940980377', 'Fechacompra': '24/06/22', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 9.0, 'Fechadenacimiento': '18/03/81', 'Codigopostalenvio': 7711, 'Tiemporealizacioncompra': 45.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e60'), 'IDCliente': 9227, 'Importecompra': '924,159168864251', 'Fechacompra': '15/07/18', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 16.0, 'Fechadenacimiento': '24/08/95', 'Codigopostalenvio': 26588, 'Tiemporealizacioncompra': 80.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e4d'), 'IDCliente': 8021, 'Importecompra': '268,500143551309', 'Fechacompra': '20/02/15', 'Categoria': 'CPU', 'Numerodeclicks': 15.0, 'Fechadenacimiento': '20/09/01', 'Codigopostalenvio': 24549, 'Tiemporealizacioncompra': 75.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e51'), 'IDCliente': 5500, 'Importecompra': '700,692696763452', 'Fechacompra': '27/09/22', 'Categoria': 'MONITOR', 'Numerodeclicks': 2.0, 'Fechadenacimiento': '10/06/98', 'Codigopostalenvio': 35571, 'Tiemporealizacioncompra': 10.0, 'Clienteexistente': 'SI'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e59'), 'IDCliente': 9087, 'Importecompra': '223,739120385146', 'Fechacompra': '14/03/15', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 11.0, 'Fechadenacimiento': '11/05/01', 'Codigopostalenvio': 33936, 'Tiemporealizacioncompra': 55.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e67'), 'IDCliente': 5509, 'Importecompra': '794,53849257176', 'Fechacompra': '09/09/19', 'Categoria': 'CPU', 'Numerodeclicks': 2.0, 'Fechadenacimiento': '07/09/81', 'Codigopostalenvio': 48010, 'Tiemporealizacioncompra': 10.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e69'), 'IDCliente': 8000, 'Importecompra': '413,278937385303', 'Fechacompra': '01/09/16', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 14.0, 'Fechadenacimiento': '25/04/82', 'Codigopostalenvio': 26324, 'Tiemporealizacioncompra': 70.0, 'Clienteexistente': 'NO'}

# %% [markdown]
# Lo mismo con el otro nodo

# %%
from pymongo import MongoClient

# Conectarse a mongodb2
cliente_mongo3 = MongoClient(
    'mongodb3',       # nombre del contenedor dentro de la red
    27017,            # puerto interno de Mongo
    replicaset='rs0', # replicaset que configuraste
    readPreference='secondaryPreferred'
)

# Seleccionamos la base y la colección
db_m3 = cliente_mongo3['bbdd']
coleccion_m3 = db_m3['compras']

# Leer 10 primeros documentos
for doc in coleccion_m3.find().limit(10):
    print(doc)
# Out:
# {'_id': ObjectId('6966a4a6d2df758917fe2e4c'), 'IDCliente': 3934, 'Importecompra': '625,570024974807', 'Fechacompra': '14/12/18', 'Categoria': 'MEMORIA', 'Numerodeclicks': 9.0, 'Fechadenacimiento': '09/05/79', 'Codigopostalenvio': 44121, 'Tiemporealizacioncompra': 45.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e47'), 'IDCliente': 1380, 'Importecompra': '529,537228589387', 'Fechacompra': '04/08/22', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 16.0, 'Fechadenacimiento': '19/02/94', 'Codigopostalenvio': 21668, 'Tiemporealizacioncompra': 80.0, 'Clienteexistente': 'SI'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e63'), 'IDCliente': 8594, 'Importecompra': '541,778075511099', 'Fechacompra': '07/08/20', 'Categoria': 'MEMORIA', 'Numerodeclicks': 9.0, 'Fechadenacimiento': '02/10/74', 'Codigopostalenvio': 25134, 'Tiemporealizacioncompra': 45.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e62'), 'IDCliente': 5854, 'Importecompra': '877,037890434317', 'Fechacompra': '29/03/21', 'Categoria': 'MEMORIA', 'Numerodeclicks': 4.0, 'Fechadenacimiento': '06/02/80', 'Codigopostalenvio': 23600, 'Tiemporealizacioncompra': 20.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e76'), 'IDCliente': 9715, 'Importecompra': '373,791521619493', 'Fechacompra': '11/02/20', 'Categoria': 'MEMORIA', 'Numerodeclicks': 11.0, 'Fechadenacimiento': '19/07/98', 'Codigopostalenvio': 27826, 'Tiemporealizacioncompra': 55.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e85'), 'IDCliente': 7187, 'Importecompra': '821,732653134701', 'Fechacompra': '30/09/16', 'Categoria': 'ALMACENAMIENTO', 'Numerodeclicks': 19.0, 'Fechadenacimiento': '04/09/92', 'Codigopostalenvio': 32520, 'Tiemporealizacioncompra': 95.0, 'Clienteexistente': 'SI'}
# {'_id': ObjectId('6966a4a6d2df758917fe2e8c'), 'IDCliente': 6517, 'Importecompra': '848,747973104967', 'Fechacompra': '28/07/16', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 20.0, 'Fechadenacimiento': '29/02/04', 'Codigopostalenvio': 3749, 'Tiemporealizacioncompra': 100.0, 'Clienteexistente': nan}
# {'_id': ObjectId('6966a4a6d2df758917fe2ec0'), 'IDCliente': 7638, 'Importecompra': '879,159232709067', 'Fechacompra': '05/07/18', 'Categoria': 'CPU', 'Numerodeclicks': 4.0, 'Fechadenacimiento': '01/04/96', 'Codigopostalenvio': 5358, 'Tiemporealizacioncompra': 20.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2ed4'), 'IDCliente': 9014, 'Importecompra': '983,67117540261', 'Fechacompra': '04/05/21', 'Categoria': 'MONITOR', 'Numerodeclicks': 17.0, 'Fechadenacimiento': '22/10/86', 'Codigopostalenvio': 31750, 'Tiemporealizacioncompra': 85.0, 'Clienteexistente': 'NO'}
# {'_id': ObjectId('6966a4a6d2df758917fe2ed5'), 'IDCliente': 7698, 'Importecompra': '156,729615901607', 'Fechacompra': '06/01/22', 'Categoria': 'RATONES Y TECLADOS', 'Numerodeclicks': 16.0, 'Fechadenacimiento': '01/12/72', 'Codigopostalenvio': 24294, 'Tiemporealizacioncompra': 80.0, 'Clienteexistente': 'NO'}

# %% [markdown]
# Ahora vamos a parar mongodb1 y comprobar que otro coge el papel de primario. Podemos hacerlo con Docker
#
# A continuación nos conectamos, por ejemplo, mongodb2
#
# *docker exec -it mongodb2 mongo*
#
# Y comprobamos que cual es el primario y podemos hacer una inserción"
#
# *rs.status()*

# %%
from pymongo import MongoClient
from pymongo.errors import OperationFailure

# --- Conexión al primario (mongodb2) ---
cliente_primario = MongoClient('mongodb2', 27017,
                               replicaset='rs0',
                               readPreference='primary')

db_primario = cliente_primario['bbdd']
coleccion_primario = db_primario['compras']

# Intentamos insertar un documento
doc_primario = {"producto": "TestPrimario", "cantidad": 5}

resultado_primario = coleccion_primario.insert_one(doc_primario)
print(f"Inserción en primario OK, id: {resultado_primario.inserted_id}")


# --- Conexión al secundario (mongodb3) ---
cliente_secundario = MongoClient('mongodb3', 27017,
                                 replicaset='rs0',
                                 readPreference='secondary')

db_secundario = cliente_secundario['bbdd']
coleccion_secundario = db_secundario['compras']

# Intentamos insertar un documento en secundario
doc_secundario = {"producto": "TestSecundario", "cantidad": 10}

try:
    resultado_secundario = coleccion_secundario.insert_one(doc_secundario)
    print(f"Inserción en secundario OK, id: {resultado_secundario.inserted_id}")
except OperationFailure as e:
    print(f"No se pudo insertar en secundario: {e}")
# Out:
# Inserción en primario OK, id: 6966ab8fd2df758917fe48fb
# Inserción en secundario OK, id: 6966ab8fd2df758917fe48fd

# %% [markdown]
# **Muy importante**, lo que está pasando no es que haya insertado en el secundario sino que dirigió la inserción al primario, pero si hago una conexión direrecat sin replicaset así:

# %%
from pymongo import MongoClient
from pymongo.errors import OperationFailure

# Conexión directa al secundario dentro del replicaset e intentar escribir
cliente_sec = MongoClient(
    'mongodb3', 
    27017, 
    replicaset='rs0',     # indicamos replicaset
    directConnection=True  # fuerza conexión directa a este nodo
)
db_sec = cliente_sec['bbdd']
coleccion_sec = db_sec['compras']

try:
    coleccion_sec.insert_one({"test": 123})
except OperationFailure as e:
    print("Fallo al intentar escribir directamente en secundario:", e)
# Out:
# ---------------------------------------------------------------------------
# NotPrimaryError                           Traceback (most recent call last)
# Cell In[38], line 15
#      12 coleccion_sec = db_sec['compras']
#      14 try:
# ---> 15     coleccion_sec.insert_one({"test": 123})
#      16 except OperationFailure as e:
#      17     print("Fallo al intentar escribir directamente en secundario:", e)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
#     901 )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:831, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     819     result = conn.command(
#     820         self._database.name,
#     821         command,
#    (...)
#     826         retryable_write=retryable_write,
#     827     )
#     829     _check_write_command_response(result)
# --> 831 self._database.client._retryable_write(
#     832     acknowledged, _insert_command, session, operation=_Op.INSERT
#     833 )
#     835 if not isinstance(doc, RawBSONDocument):
#     836     return doc.get("_id")
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2082, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2068 """Execute an operation with consecutive retries if possible
#    2069
#    2070 Returns func()'s return value on success. On error retries the same
#    (...)
#    2079 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2080 """
#    2081 with self._tmp_session(session) as s:
# -> 2082     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2897, in _ClientConnectionRetryable._write(self)
#    2889         if self._retrying:
#    2890             _debug_log(
#    2891                 _COMMAND_LOGGER,
#    2892                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)
#    2895                 operationId=self._operation_id,
#    2896             )
# -> 2897         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2898 except PyMongoError as exc:
#    2899     if not self._retryable:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:819, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     816 if bypass_doc_val is not None:
#     817     command["bypassDocumentValidation"] = bypass_doc_val
# --> 819 result = conn.command(
#     820     self._database.name,
#     821     command,
#     822     write_concern=write_concern,
#     823     codec_options=self._write_response_codec_options,
#     824     session=session,
#     825     client=self._database.client,
#     826     retryable_write=retryable_write,
#     827 )
#     829 _check_write_command_response(result)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,  # type: ignore[arg-type]
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/helpers_shared.py:267, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     265 if code is not None:
#     266     if code in _NOT_PRIMARY_CODES:
# --> 267         raise NotPrimaryError(errmsg, response)
#     268 elif HelloCompat.LEGACY_ERROR in errmsg or "node is recovering" in errmsg:
#     269     raise NotPrimaryError(errmsg, response)
#
# NotPrimaryError: not primary, full error: {'topologyVersion': {'processId': ObjectId('69669ceb8d23de79974a538d'), 'counter': 5}, 'ok': 0.0, 'errmsg': 'not primary', 'code': 10107, 'codeName': 'NotWritablePrimary', '$clusterTime': {'clusterTime': Timestamp(1768336829, 1), 'signature': {'hash': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'keyId': 0}}, 'operationTime': Timestamp(1768336829, 1)}

# %% [markdown]
# # Sharding

# %% [markdown]
# ## Conexión a mongos

# %%
from pymongo import MongoClient

#Utiliza la IP de tu anfitrión
cliente = MongoClient('mongos', 27017)

#Creamos la instancia para interactuar con la colección de clientes y pedidos
bbdd = cliente.tienda
coleccion_clientes = bbdd.clientes
coleccion_pedidos = bbdd.pedidos

# %% [markdown]
# ## Inserción de datos de clientes y de pedidos

# %%
#Inserción de documentos de clientes
documentos_clientes = [
    {'IDCliente': 1, 'Nombre': "Juan", 'Apellidos': "Fernández"},
    {'IDCliente': 2, 'Nombre': "María", 'Apellidos': "Fernández"},
    {'IDCliente': 3, 'Nombre': "Carolina", 'Apellidos': "Pérez"}
]

resultado = coleccion_clientes.insert_many(documentos_clientes)
print("Se han insertado",len(resultado.inserted_ids),"clientes")

# %%
#Inserción de documentos de pedidos
documentos_pedidos = [
    {'IDPedido': 1, 'IDCliente': 1, 'Importe': 3.24, 'Ciudad': "Vigo"},
    {'IDPedido': 2, 'IDCliente': 1, 'Importe': 8.01, 'Ciudad': "Pontevedra"},
    {'IDPedido': 3, 'IDCliente': 3, 'Importe': 28.12, 'Ciudad': "A Coruña"},
    {'IDPedido': 4, 'IDCliente': 1, 'Importe': 56.78, 'Ciudad': "Vigo"},
    {'IDPedido': 5, 'IDCliente': 2, 'Importe': 0.12, 'Ciudad': "Madrid"},
    {'IDPedido': 6, 'IDCliente': 3, 'Importe': 99.45, 'Ciudad': "Barcelona"},
    {'IDPedido': 7, 'IDCliente': 3, 'Importe': 2.1, 'Ciudad': "Valencia"},
    {'IDPedido': 8, 'IDCliente': 1, 'Importe': 9, 'Ciudad': "Ourense"},
    {'IDPedido': 9, 'IDCliente': 1, 'Importe': 32.56, 'Ciudad': "Lugo"},
    {'IDPedido': 10, 'IDCliente': 3, 'Importe': 5.45, 'Ciudad': "Santiago"},
]

resultado = coleccion_pedidos.insert_many(documentos_pedidos)
print("Se han insertado",len(resultado.inserted_ids),"pedidos")

# %% [markdown]
# ## Comprobación de datos insertados

# %%
#Número de documentos en colección clientes
num_clientes = coleccion_clientes.count_documents({})
print("Hay",num_clientes,"clientes")

#Número de documentos en colección pedidos
num_pedidos = coleccion_pedidos.count_documents({})
print("Hay",num_pedidos,"pedidos")

# %% [markdown]
# ## Conexión a mongoshard1 y cuenta de documentos

# %%
from pymongo import MongoClient

#Como JupyterLab y los nodos de Mongo están conectados a través de la red interna
# establecemos la conexión a travñes de dicha red. Todos escuchan en esa red en el puerto 27017.
# Si te quisieses conectar a través del anfitrión, debes hacerlo al puerto mapeado, en esta caso
# al 27019
cliente = MongoClient('mongoshard1', 27017)

#Creamos la instancia para interactuar con la colección de clientes y pedidos
bbdd = cliente.tienda
coleccion_clientes = bbdd.clientes
coleccion_pedidos = bbdd.pedidos

#Número de documentos en colección clientes
num_clientes = coleccion_clientes.count_documents({})
print("Hay",num_clientes,"clientes")

#Número de documentos en colección pedidos
num_pedidos = coleccion_pedidos.count_documents({})
print("Hay",num_pedidos,"pedidos")

# %% [markdown]
# ## Conexión a mongoshard2 y cuenta de documentos

# %%
from pymongo import MongoClient

#Como JupyterLab y los nodos de Mongo están conectados a través de la red interna
# establecemos la conexión a travñes de dicha red. Todos escuchan en esa red en el puerto 27017.
# Si te quisieses conectar a través del anfitrión, debes hacerlo al puerto mapeado, en esta caso
# al 27020
cliente = MongoClient('mongoshard2', 27017)

#Creamos la instancia para interactuar con la colección de clientes y pedidos
bbdd = cliente.tienda
coleccion_clientes = bbdd.clientes
coleccion_pedidos = bbdd.pedidos

#Número de documentos en colección clientes
num_clientes = coleccion_clientes.count_documents({})
print("Hay",num_clientes,"clientes")

#Número de documentos en colección pedidos
num_pedidos = coleccion_pedidos.count_documents({})
print("Hay",num_pedidos,"pedidos")
